# %% [markdown]
# # 캐시미션에서 내려받은 파일별 raw json을 행 구분으로 병합

# %%
import os
import json


# 경로에 있는 raw json파일들 하나로 병합
def merge_json_files(directory_path, output_file_path):
    json_list = []

    # 파일 순회
    for filename in os.listdir(directory_path):
        if filename.endswith('.json'):
            file_path = os.path.join(directory_path, filename)
            with open(file_path, 'r', encoding='utf-8') as f:
                # 각 파일을 로드 후 리스트 추가
                json_data = json.load(f)
                json_list.append(json_data)


    # 행 구분으로 저장
    with open(output_file_path, 'w', encoding='utf-8') as outfile:
        for item in json_list:
            outfile.write(json.dumps(item, ensure_ascii=False) + '\n')

    print(f"raw json {output_file_path}병합 완")


# 인풋 경로
directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_json_1022'
output_file_path = '/content/poc_annotation.json'  # 아웃풋 경로


# 실행
merge_json_files(directory_path, output_file_path)
# Out:
# raw json /content/poc_annotation.json병합 완

# %% [markdown]
# # 행구분된 json 파일 납품 구조로 변경
# ## 상세 조건은 주석확인

# %%
# 캐시미션 추출되는 json 예시
#   {
#         "classClientId": "background",
#         "type": "BOX",
#         "coordinates": {
#           "x1": 0,
#           "y1": 0,
#           "x2": 1,
#           "y2": 1,
#           "type": "BOX"
#         },
#         "submissionItems": [
#           {
#             "classItemClientId": "c4d32d3c",
#             "type": "RADIO",
#             "answer": null,
#             "selectionClientIds": ["1001"]
#           },
#           {
#             "classItemClientId": "f2569f44",
#             "type": "RADIO",
#             "answer": null,
#             "selectionClientIds": ["1000"]
#           },
#           {
#             "classItemClientId": "53697e64",
#             "type": "TEXT_STRING",
#             "answer": "088,159,117,1",
#             "selectionClientIds": []
#           }
#         ],
#         "clientId": "e69f7e2d-92b6-4360-bcfb-334020c0932f",
#         "status": "DONE",
#         "failedReasons": []
#       },

# %% [markdown]
# ## 파일, json 매칭 -> 이거는 인풋 단계에서 작업한 raw image만 잘 넣으면 필요가 없음(수정필요)

# %%
# import os
# import json

# # JSON 파일에서 파일 이름을 추출하는 함수
# def extract_filenames_from_json(json_file_path):
#     filenames = []
#     with open(json_file_path, 'r', encoding='utf-8') as file:
#         for line in file:  # 한 줄씩 JSON 객체를 읽어옴
#             try:
#                 data = json.loads(line.strip())
#                 filenames.append(data['source']['fileName'])  # 파일 이름 추출
#             except json.JSONDecodeError as e:
#                 print(f"Error decoding JSON: {e}")
#     return filenames

# # 디렉토리에서 이미지 파일 목록을 가져오는 함수
# def get_image_filenames_from_directory(directory_path):
#     image_filenames = []
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             image_filenames.append(filename)
#     return image_filenames

# # JSON 파일과 이미지 디렉토리 경로
# json_file_path = '/content/poc_annotation.json'  # JSON 파일 경로
# image_directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_1022'  # 이미지 파일이 저장된 디렉토리 경로

# # JSON 파일에서 파일 이름을 추출
# json_filenames = extract_filenames_from_json(json_file_path)

# # 디렉토리에서 이미지 파일 이름을 가져옴
# image_filenames = get_image_filenames_from_directory(image_directory_path)


# json_filenames_with_extension = [f"{os.path.splitext(filename)[0]}.jpg" for filename in json_filenames]  # 예: jpg 확장자 사용

# missing_in_directory = [filename for filename in json_filenames_with_extension if filename not in image_filenames]


# missing_in_json = [filename for filename in image_filenames if filename not in json_filenames_with_extension]


# print("JSON존재  raw에 없는 파일들:")
# print(missing_in_directory)

# print("\n raw에 있지만 JSON에 없음:")
# print(missing_in_json)

# %% [markdown]
# # 캐시미션 json data - raw image 매칭

# %%
import json
import os

# 원본 JSON 파일 경로
input_json_file = '/content/poc_annotation.json'

# 이미지가 저장된 디렉토리 경로
image_directory = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_1022'

# JSON 파일에 있지만, 이미지 디렉토리에 없는 파일명을 저장할 리스트
missing_images = []

# 이미지 디렉토리 내 파일 이름 리스트 가져오기 (확장자 포함)
image_files = os.listdir(image_directory)

# 이미지 파일명을 소문자로 변환 (대소문자 구분 없게 처리)
image_files_lower = [f.lower() for f in image_files]

# JSON 파일에서 파일명 추출 및 이미지 디렉토리에서 존재 여부 확인
with open(input_json_file, 'r', encoding='utf-8') as infile:
    for line in infile:
        try:
            # JSON 파일의 각 라인에서 'fileName' 추출
            data = json.loads(line.strip())
            json_file_name = data.get('source', {}).get('fileName', '').lower()  # 소문자로 변환

            # 이미지 디렉토리에서 해당 파일이 있는지 확인
            if json_file_name and json_file_name not in image_files_lower:
                missing_images.append(json_file_name)

        except json.JSONDecodeError as e:
            print(f"Error parsing line: {line}")
            print(f"Error message: {e}")

# JSON에 있지만 이미지 디렉토리에 없는 파일명 출력
if missing_images:
    print("JSON에는 있지만 이미지 디렉토리에 없는 파일들:")
    for missing in missing_images:
        print(missing)
else:
    print("모든 JSON 파일이 이미지 디렉토리 내에 존재합니다.")

# %% [markdown]
# # 캐시미션 json -> 납품구조로 변경

# %%
# 10.24 수정

import os
from PIL import Image
import json


def get_image_dimensions(directory_path):
    image_dimensions = {}

    # 이미지 파일 순회
    for filename in os.listdir(directory_path):
        try:
            # 파일명 출력해서 한글 파일명 디버깅
            print(f"Processing file: {filename}")

            # 이미지 확장자 필터링
            if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(directory_path, filename)

                # 이미지 열어서 크기 추출
                with Image.open(file_path) as img:
                    width, height = img.size
                    image_dimensions[filename] = {"width": width, "height": height}

        except Exception as e:
            print(f"Error processing file {filename}: {e}")

    return image_dimensions

# 인풋 경로
directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_1022'

# 원본 raw data width, height 반영
image_info = get_image_dimensions(directory_path)


# 카테고리별 순서를 지정 -> 캐시미션 업데이트 후 group_underaly값 변경해야됨. -> 반영 10.17에 반영 예정
category_order = [
    "background", "group_underlay", "image", "sticker",
    "text_underlay", "decoration", "text", "item", "logo"
]

# JSON 데이터를 변환하는 함수
def convert_json(data, index, image_info):
    # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
    file_name = data['source']['fileName']
    if file_name in image_info:
        image_width = image_info[file_name]['width']
        image_height = image_info[file_name]['height']
        canvas_size = [image_width, image_height]
    else:
        # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
        canvas_size = [1, 1]

    # 파일 정보 변환
    new_data = {
        "id": index,  # id는 각 파일별로 고유하게 설정
        "file_name": data['source']['fileName'],
        "canvas_size": canvas_size,
        "type": "MMS",
        "elements": []
    }

    sorted_units = sorted(
        [unit for unit in data['units'] if unit.get('status') != 'WRONG'],  # status가 "wrong"인 애들은 제외
        key=lambda x: (
            category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
            x['coordinates']['y1'],  # 상단 기준 정렬
            x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
        )
    )

    # element_id를 추적할 변수
    element_id = 0

    # 각 정렬된 unit항목 내 정보들 처리
    for unit in sorted_units:
        element = {
            "element_id": element_id,
            "category": unit['classClientId'],
            "group": None,  # 기본값 설정
            "bbox": [],  # 나중에 채워짐
            "raw_text": "",
            "text_newline": [],
            "text_alignment": "",
            "highlight_text": "",
            "font_color": [],
            "font_type": None,
            "font_size": None,
            "highlight_color": [],
            "is_gradient": None,
            "gradient_color": None,
            "is_background": 0,
            "background_color": []
        }

        # 좌표 처리 (bbox와 raw_bbox)
        x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

        # 이미지 크기 bbox 좌표 조건 반영
        center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
        center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
        box_width = int((x2 - x1) * canvas_size[0])
        box_height = int((y2 - y1) * canvas_size[1])

        # bbox 값 설정
        bbox = [center_x, center_y, element_id, box_width, box_height]
        element['bbox'] = bbox



        # background 조건 적용'

        # background_group
        if unit['classClientId'] == "background" and len(unit['submissionItems']) > 3:
          element["font_color"] =None
          element["highlight_color"] =None


          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element['group'] = None  # 기타 값 처리
          else:
            element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정



        # background_is_gradient
          selectionClientId_3 = unit['submissionItems'][1]['selectionClientIds'][0]
          element['is_gradient'] = 1 if selectionClientId_3 == "1001" else 0



        # background_is_background
          selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
          element['is_background'] = 1 if selectionClientId_2 == "1000" else 2




        # background_background_color
          if element['is_background'] == 1:
            background_color = unit['submissionItems'][3]['answer']
            if "RGB" in background_color:
              rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
              rgb_values = [int(c) for c in rgb_values_str.split(",")]
              element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
            else:
              element['background_color'] = ["color error"]
          else:
            element['background_color'] = [file_name]








        # group_underlay 조건 적용

        # group_underlay_group
        elif unit['classClientId'] == "group_underlay" and len(unit['submissionItems']) > 1:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element['group'] = None  # 기타 값 처리
          else:
            element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정


        # group_underlay_background_color
          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color error"]


        # group_underlay_is_gradient
          selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
          element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0



        # image 조건 적용

        # image_group
        elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




        # sticker 조건 적용

        # sticker_group
        elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 2:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None

        # sticker_background_color
          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color error"]

        # sticker_is_gradient
          selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
          element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0


        # text_underlay 조건 적용

        # text_underlay_group
        elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None


        # text_underlay_background_color
          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color"]


        # text_underlay_is_gradient
          selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
          element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0






        # decoration 조건 적용

        # decoration group
        elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




        # text 조건 적용

        # text group
        elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None

        # raw_text
          element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""

        # text_newline
          element['text_newline'] = unit['submissionItems'][2]['answer'].split("\n") if unit['submissionItems'][2]['answer'] else []

        # text_alignment
          if len(unit['submissionItems']) > 3 and unit['submissionItems'][3]['selectionClientIds']:
            selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
            if selectionClientId_4 == "1000":
              element['text_alignment'] = "middle"
            elif selectionClientId_4 == "1001":
              element['text_alignment'] = "left"
            elif selectionClientId_4 == "1002":
              element['text_alignment'] = "right"
          else:
            element['text_alignment'] = ""

        # highlight_text
          element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""




        # text_font_color
          if len(unit['submissionItems']) > 5 and unit['submissionItems'][5]['answer']:
            font_color = unit['submissionItems'][5]['answer']

            if "RGB" in font_color:
              rgb_values_str = font_color.replace("RGB(", "").replace(")", "")
              font_color = [int(c) for c in rgb_values_str.split(",")]
              element['font_color'] = font_color + [1]
            else:
              element['font_color'] = []
          else:
            element['font_color'] = []


        # text_highlight_color
          if len(unit['submissionItems']) > 6 and unit['submissionItems'][6]['answer']:
            highlight_color = unit['submissionItems'][6]['answer']

            if "RGB" in highlight_color:
              rgb_values_str = highlight_color.replace("RGB(", "").replace(")", "")
              highlight_color = [int(c) for c in rgb_values_str.split(",")]
              element['highlight_color'] = highlight_color+ [1]
            else:
              element['highlight_color'] = []

          else:
            element['highlight_color'] = []



        # text_is_gradient
          selectionClientId_2 = unit['submissionItems'][7]['selectionClientIds'][0]
          element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0







          # item 조건 적용
        elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




          # logo 조건 적용
        elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
          element["font_color"] =None
          element["highlight_color"] =None
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None


        # element 추가
        new_data['elements'].append(element)

        # element_id 증가
        element_id += 1

    return new_data

file_path = '/content/poc_annotation.json'

# 줄 단위로 JSON 객체 로드
output_json_list = []
with open(file_path, 'r') as f:
    for index, line in enumerate(f):
        # 각 줄을 JSON 객체로 변환
        input_json = json.loads(line.strip())
        # 변환 실행
        output_json = convert_json(input_json, index, image_info)
        output_json_list.append(output_json)

# 변환된 JSON 리스트
print(json.dumps(output_json_list, indent=4))

# 변환된 JSON 저장
output_file_path = '/content/output.json'

with open(output_file_path, 'w', encoding='utf-8') as outfile:
    json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

print(f"변환된 JSON 파일 {output_file_path}에 저장")

# %% [markdown]
# # (안씀)10.18ver 보존

# %%
# # 10.18 수정

# import os
# from PIL import Image
# import json


# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일 순회
#     for filename in os.listdir(directory_path):
#         try:
#             # 파일명 출력해서 한글 파일명 디버깅
#             print(f"Processing file: {filename}")

#             # 이미지 확장자 필터링
#             if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
#                 file_path = os.path.join(directory_path, filename)

#                 # 이미지 열어서 크기 추출
#                 with Image.open(file_path) as img:
#                     width, height = img.size
#                     image_dimensions[filename] = {"width": width, "height": height}

#         except Exception as e:
#             print(f"Error processing file {filename}: {e}")

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_1022'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정 -> 캐시미션 업데이트 후 group_underaly값 변경해야됨. -> 반영 10.17에 반영 예정
# category_order = [
#     "background", "group_underlay", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     # sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))
#     # sorted_units = sorted(data['units'], key=lambda x: (
#     # category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#     # x['coordinates']['y1'],  # 상단 기준 정렬
#     # x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#     # ))
#     sorted_units = sorted(
#         [unit for unit in data['units'] if unit.get('status') != 'WRONG'],  # status가 "wrong"인 애들은 제외
#         key=lambda x: (
#             category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#             x['coordinates']['y1'],  # 상단 기준 정렬
#             x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#         )
#     )

#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox



#         # background 조건 적용'

#         # background_group
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 3:
#           element["font_color"] =None
#           element["highlight_color"] =None


#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element['group'] = None  # 기타 값 처리
#           else:
#             element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정



#         # background_is_gradient
#           selectionClientId_3 = unit['submissionItems'][1]['selectionClientIds'][0]
#           element['is_gradient'] = 1 if selectionClientId_3 == "1001" else 0



#         # background_is_background
#           selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
#           element['is_background'] = 1 if selectionClientId_2 == "1000" else 2




#         # background_background_color
#           if element['is_background'] == 1:
#             background_color = unit['submissionItems'][3]['answer']
#             if "RGB" in background_color:
#               rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
#               rgb_values = [int(c) for c in rgb_values_str.split(",")]
#               element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
#             else:
#               element['background_color'] = ["color error"]
#           else:
#             element['background_color'] = [file_name]








#         # group_underlay 조건 적용

#         # group_underlay_group
#         elif unit['classClientId'] == "group_underlay" and len(unit['submissionItems']) > 1:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element['group'] = None  # 기타 값 처리
#           else:
#             element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정


#         # group_underlay_background_color
#           background_color = unit['submissionItems'][1]['answer']
#           if "RGB" in background_color:
#             rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
#             rgb_values = [int(c) for c in rgb_values_str.split(",")]
#             element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
#           else:
#             element['background_color'] = ["color error"]


#         # group_underlay_is_gradient
#           selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
#           element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0



#         # image 조건 적용

#         # image_group
#         elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None




#         # sticker 조건 적용

#         # sticker_group
#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 2:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None

#         # sticker_background_color
#           background_color = unit['submissionItems'][1]['answer']
#           if "RGB" in background_color:
#             rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
#             rgb_values = [int(c) for c in rgb_values_str.split(",")]
#             element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
#           else:
#             element['background_color'] = ["color error"]

#         # sticker_is_gradient
#           selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
#           element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0


#         # text_underlay 조건 적용

#         # text_underlay_group
#         elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None


#         # text_underlay_background_color
#           background_color = unit['submissionItems'][1]['answer']
#           if "RGB" in background_color:
#             rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
#             rgb_values = [int(c) for c in rgb_values_str.split(",")]
#             element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
#           else:
#             element['background_color'] = ["color"]


#         # text_underlay_is_gradient
#           selectionClientId_2 = unit['submissionItems'][2]['selectionClientIds'][0]
#           element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0






#         # decoration 조건 적용

#         # decoration group
#         elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None




#         # text 조건 적용

#         # text group
#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None

#         # raw_text
#           element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""

#         # text_newline
#           element['text_newline'] = unit['submissionItems'][2]['answer'].split("\n") if unit['submissionItems'][2]['answer'] else []

#         # text_alignment
#           if len(unit['submissionItems']) > 3 and unit['submissionItems'][3]['selectionClientIds']:
#             selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
#             if selectionClientId_4 == "1000":
#               element['text_alignment'] = "middle"
#             elif selectionClientId_4 == "1001":
#               element['text_alignment'] = "left"
#             elif selectionClientId_4 == "1002":
#               element['text_alignment'] = "right"
#           else:
#             element['text_alignment'] = ""

#         # highlight_text
#           element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""




#         # text_font_color
#           if len(unit['submissionItems']) > 5 and unit['submissionItems'][5]['answer']:
#             font_color = unit['submissionItems'][5]['answer']

#             if "RGB" in font_color:
#               rgb_values_str = font_color.replace("RGB(", "").replace(")", "")
#               font_color = [int(c) for c in rgb_values_str.split(",")]
#               element['font_color'] = font_color + [1]
#             else:
#               element['font_color'] = []
#           else:
#             element['font_color'] = []


#         # text_highlight_color
#           if len(unit['submissionItems']) > 6 and unit['submissionItems'][6]['answer']:
#             highlight_color = unit['submissionItems'][6]['answer']

#             if "RGB" in highlight_color:
#               rgb_values_str = highlight_color.replace("RGB(", "").replace(")", "")
#               highlight_color = [int(c) for c in rgb_values_str.split(",")]
#               element['highlight_color'] = highlight_color+ [1]
#             else:
#               element['highlight_color'] = []

#           else:
#             element['highlight_color'] = []



#         # text_is_gradient
#           selectionClientId_2 = unit['submissionItems'][7]['selectionClientIds'][0]
#           element['is_gradient'] = 1 if selectionClientId_2 == "1001" else 0







#           # item 조건 적용
#         elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None




#           # logo 조건 적용
#         elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
#           element["font_color"] =None
#           element["highlight_color"] =None
#           if unit['submissionItems'][0]['selectionClientIds']:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             if selectionClientId_1 == "1000":
#               element['group'] = None
#             elif selectionClientId_1 == "1001":
#               element['group'] = "0"
#             elif selectionClientId_1 == "1002":
#               element['group'] = "1"
#             elif selectionClientId_1 == "1003":
#               element['group'] = "2"
#             else:
#               element["group"] = None
#           else:
#             selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
#             element['group'] = None


#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 로드
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     219.3,
#                     597.7,
#                     8,
#                     393,
#                     38
#                 ],
#                 "raw_text": "\uc9c0\uae08 \ubc14\ub85c ifland\uc5d0\uc11c \ub9cc\ub098\ubcf4\uc138\uc694!",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "ifland",
#                 "font_color": [
#                     248,
#                     252,
#                     244,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     225,
#                     19,
#                     117,
#                     1
#                 ],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     137.4,
#                     674.1,
#                     9,
#                     228,
#                     33
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 84,
#         "file_name": "0405311328548350627431.jpeg",
#         "canvas_size": [
#             480,
#             320
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     240.0,
#                     160.0,
#                     0,
#                     480,
#                     320
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 1,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     24,
#                     153,
#                     255,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     246.3,
#                     112.0,
#                     1,
#                     269,
#                     223
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     197.4,
#                     165.1,
#                     2,
#                     129,
#                     37
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     77,
#                     243,
#                     11,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     305.7,
#                     36.1,
#                     3,
#                     44,
#                     43
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     374.9,
#                     63.4,
#                     4,
#                     28,
#                     25
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     421.7,
#                     115.2,
#                     5,
#                     79,
#                     52
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     85.3,
#                     124.9,
#                     6,
#                     62,
#                     51
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     452.1,
#                     207.6,
#                     7,
#                     55,
#                     99
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     43.4,
#                     171.1,
#                     8,
#                     24,
#                     24
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     385.9,
#                     216.9,
#                     9,
#                     28,
#                     27
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     196.3,
#                     164.9,
#                     10,
#                     104,
#                     17
#                 ],
#                 "raw_text": "\u2665 \uc120\ucc29\uc21c 500\uba85!",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "\u2665",
#                 "font_color": [
#                     9,
#                     60,
#                     2,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     122,
#                     69,
#                     1
#                 ],
#                 "is_gradient": 1,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     208.6,
#                     236.2,
#                     11,
#                     385,
#                     67
#                 ],
#                 "raw_text": "READY FOR THE COOL SUMMER?",
#                 "text_newline": [
#                     "READY FOR",
#                     "THE COOL SUMMER?"
#                 ],
#                 "text_alignment": "left",
#                 "highlight_text": "",
#                 "font_color": [
#                     254,
#                     255,
#                     254,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     92.2,
#                     289.6,
#                     12,
#                     147,
#                     13
#                 ],
#                 "raw_text": "\uce74\uce74\uc624\ud504\ub80c\uc988 \uc5ec\ub984 \ud2b9\ubcc4 \ud560\uc778\uc804 OPEN",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     160,
#                     232,
#                     221,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     442.7,
#                     36.3,
#                     13,
#                     43,
#                     40
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     55.8,
#                     34.6,
#                     14,
#                     76,
#                     31
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 85,
#         "file_name": "0309061241318298765995.jpg",
#         "canvas_size": [
#             640,
#             480
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     240.0,
#                     0,
#                     640,
#                     480
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     494.3,
#                     148.3,
#                     1,
#                     188,
#                     111
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     320.5,
#                     256.4,
#                     2,
#                     257,
#                     35
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     29,
#                     29,
#                     29,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     454.8,
#                     3,
#                     640,
#                     50
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     0,
#                     71,
#                     209,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     324.6,
#                     29.7,
#                     4,
#                     257,
#                     20
#                 ],
#                 "raw_text": "\ube4c\ub808\ud130 \ub9c8\uc774\ud480 \uc2e0\uaddc \uac00\uc785 \uc774\ubca4\ud2b8",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     38,
#                     38,
#                     37,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     211.2,
#                     147.8,
#                     5,
#                     318,
#                     105
#                 ],
#                 "raw_text": "\uc678\uad6d\uc5b4 \uacf5\ubd80\ud558\uace0 \uc120\ubb3c \ubc1b\uc544\uac00\uc138\uc694",
#                 "text_newline": [
#                     "\uc678\uad6d\uc5b4 \uacf5\ubd80\ud558\uace0",
#                     "\uc120\ubb3c \ubc1b\uc544\uac00\uc138\uc694"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     43,
#                     43,
#                     43,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.3,
#                     254.9,
#                     6,
#                     207,
#                     19
#                 ],
#                 "raw_text": "GS25 \uae08\uc561\uad8c \uc120\ucc29\uc21c 100\uba85",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     213.7,
#                     352.0,
#                     7,
#                     324,
#                     72
#                 ],
#                 "raw_text": "5\uac1c \uc5b8\uc5b4 + \ud1a0\uc775 \uacf5\ubd80\ud558\ub294\ub370 \uc774\ub7f0 \uac00\uaca9\uc740 \ucc98\uc74c\uc774\uc9c0?",
#                 "text_newline": [
#                     "5\uac1c \uc5b8\uc5b4 + \ud1a0\uc775 \uacf5\ubd80\ud558\ub294\ub370",
#                     "\uc774\ub7f0 \uac00\uaca9\uc740 \ucc98\uc74c\uc774\uc9c0?"
#                 ],
#                 "text_alignment": "left",
#                 "highlight_text": "",
#                 "font_color": [
#                     1,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     532.6,
#                     332.5,
#                     8,
#                     111,
#                     30
#                 ],
#                 "raw_text": "-14,900\uc6d0-",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     210,
#                     101,
#                     101,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     517.7,
#                     375.5,
#                     9,
#                     139,
#                     36
#                 ],
#                 "raw_text": "\uc6d4 9,900\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     29,
#                     29,
#                     29,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.7,
#                     455.0,
#                     10,
#                     461,
#                     22
#                 ],
#                 "raw_text": "#\uc601\uc5b4 #\uc911\uad6d\uc5b4 #\uc77c\ubcf8\uc5b4 #\uc2a4\ud398\uc778\uc5b4 #\ubca0\ud2b8\ub0a8\uc5b4 #\ud1a0\uc775",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     213,
#                     219,
#                     240,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     60.1,
#                     29.0,
#                     11,
#                     84,
#                     19
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     572.4,
#                     29.4,
#                     12,
#                     101,
#                     20
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 86,
#         "file_name": "0310051442188236195014.jpeg",
#         "canvas_size": [
#             720,
#             720
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     360.0,
#                     360.0,
#                     0,
#                     720,
#                     720
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 2,
#                 "background_color": [
#                     "0310051442188236195014.jpeg"
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     289.1,
#                     517.6,
#                     1,
#                     452,
#                     321
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     576.9,
#                     551.4,
#                     2,
#                     164,
#                     281
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     509.1,
#                     382.4,
#                     3,
#                     89,
#                     87
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     250,
#                     255,
#                     5,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 4,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     359.6,
#                     81.6,
#                     4,
#                     527,
#                     58
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     4,
#                     4,
#                     4,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     361.1,
#                     82.1,
#                     5,
#                     425,
#                     31
#                 ],
#                 "raw_text": "\uc5d0\uc774\ub2f7 X New iPhone DRAW \uc774\ubca4\ud2b8",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     164,
#                     154,
#                     119,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     361.5,
#                     176.8,
#                     6,
#                     444,
#                     56
#                 ],
#                 "raw_text": "\uc751\ubaa8 \uc548 \ud558\uba74 \ud6c4\ud68c\ub9c9\uc2ec",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     360.5,
#                     268.1,
#                     7,
#                     488,
#                     92
#                 ],
#                 "raw_text": "\uc5d0\uc774\ub2f7 \uce98\ub9b0\ub354\uc5d0 DRAW \uc77c\uc815\uc744 \ubbf8\ub9ac \ub4f1\ub85d\ud574 \ubcf4\uc138\uc694!",
#                 "text_newline": [
#                     "\uc5d0\uc774\ub2f7 \uce98\ub9b0\ub354\uc5d0 DRAW \uc77c\uc815\uc744",
#                     "\ubbf8\ub9ac \ub4f1\ub85d\ud574 \ubcf4\uc138\uc694!"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     157,
#                     157,
#                     157,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     508.7,
#                     382.6,
#                     8,
#                     69,
#                     23
#                 ],
#                 "raw_text": "\uc608\uc57d\uad8c",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     62,
#                     46,
#                     212,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 87,
#         "file_name": "0308081209428034430251.jpeg",
#         "canvas_size": [
#             480,
#             320
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     240.0,
#                     160.0,
#                     0,
#                     480,
#                     320
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 1,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     196,
#                     255,
#                     227,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     356.9,
#                     210.5,
#                     1,
#                     246,
#                     219
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     175.0,
#                     223.3,
#                     2,
#                     116,
#                     44
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     255,
#                     64,
#                     79,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     418.1,
#                     37.6,
#                     3,
#                     82,
#                     75
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     176.7,
#                     53.1,
#                     4,
#                     312,
#                     21
#                 ],
#                 "raw_text": "\ud504\ub9ac\ubbf8\uc5b4\ub9ac\uadf8, MLB, NBA \ub3c5\uc810 \uc0dd\uc911\uacc4!",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     49,
#                     108,
#                     226,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     193.0,
#                     90.8,
#                     5,
#                     344,
#                     32
#                 ],
#                 "raw_text": "SPOTV NOW + \uc6b0\uc8fc\ud328\uc2a4",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     66.4,
#                     221.0,
#                     6,
#                     90,
#                     22
#                 ],
#                 "raw_text": "-\uc6d4 9,900\uc6d0-",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     85,
#                     85,
#                     85,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     175.9,
#                     218.8,
#                     7,
#                     95,
#                     15
#                 ],
#                 "raw_text": "9\uc6d4 30\uc77c\uae4c\uc9c0!",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     233,
#                     233,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     131.7,
#                     272.3,
#                     8,
#                     222,
#                     36
#                 ],
#                 "raw_text": "\uac00\uc785 \uccab \ub2ec 1,000\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     64,
#                     79,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     416.9,
#                     40.5,
#                     9,
#                     51,
#                     21
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     406.0,
#                     299.4,
#                     10,
#                     111,
#                     17
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 88,
#         "file_name": "0309181639328307925536.jpg",
#         "canvas_size": [
#             640,
#             860
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     430.0,
#                     0,
#                     640,
#                     860
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     222,
#                     214,
#                     251,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     554.8,
#                     1,
#                     640,
#                     607
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     115.0,
#                     744.2,
#                     2,
#                     129,
#                     130
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     65,
#                     28,
#                     196,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     320.8,
#                     247.9,
#                     3,
#                     326,
#                     46
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     73,
#                     35,
#                     201,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     323.0,
#                     127.5,
#                     4,
#                     598,
#                     49
#                 ],
#                 "raw_text": "\uc628\ub77c\uc778 \uc778\uae30 \uc0c1\ud488, \uc785\uc18c\ubb38\ub09c \uc18c\uacf1\ucc3d!",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     68,
#                     31,
#                     189,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.5,
# ...
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": "0",
#                 "bbox": [
#                     73.6,
#                     377.9,
#                     13,
#                     67,
#                     32
#                 ],
#                 "raw_text": "51%",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     252,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": "1",
#                 "bbox": [
#                     117.2,
#                     767.3,
#                     14,
#                     167,
#                     58
#                 ],
#                 "raw_text": "\uc560\ud50c \uc5d0\uc5b4\ud31f \ud504\ub85c 2\uc138\ub300 USB-C",
#                 "text_newline": [
#                     "\uc560\ud50c \uc5d0\uc5b4\ud31f \ud504\ub85c",
#                     "2\uc138\ub300 USB-C"
#                 ],
#                 "text_alignment": "left",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 15,
#                 "category": "text",
#                 "group": "2",
#                 "bbox": [
#                     437.3,
#                     770.0,
#                     15,
#                     212,
#                     62
#                 ],
#                 "raw_text": "\uc544\uc774\ub974 24SS \ubd04\uc2e0\uc0c1 \uce68\uad6c 30\uc885 \ubaa8\uc74c\uc804",
#                 "text_newline": [
#                     "\uc544\uc774\ub974 24SS \ubd04\uc2e0\uc0c1",
#                     "\uce68\uad6c 30\uc885 \ubaa8\uc74c\uc804"
#                 ],
#                 "text_alignment": "left",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 16,
#                 "category": "text",
#                 "group": "1",
#                 "bbox": [
#                     198.5,
#                     821.3,
#                     16,
#                     155,
#                     38
#                 ],
#                 "raw_text": "312,570\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     235,
#                     73,
#                     38,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 17,
#                 "category": "text",
#                 "group": "2",
#                 "bbox": [
#                     493.5,
#                     825.6,
#                     17,
#                     148,
#                     38
#                 ],
#                 "raw_text": "9,900\uc6d0~",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     235,
#                     73,
#                     38,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 18,
#                 "category": "text",
#                 "group": "2",
#                 "bbox": [
#                     373.0,
#                     821.8,
#                     18,
#                     66,
#                     28
#                 ],
#                 "raw_text": "54%",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     251,
#                     255,
#                     252,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 19,
#                 "category": "text",
#                 "group": "1",
#                 "bbox": [
#                     73.6,
#                     822.9,
#                     19,
#                     58,
#                     26
#                 ],
#                 "raw_text": "22%",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     251,
#                     254,
#                     251,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 20,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     570.4,
#                     40.6,
#                     20,
#                     90,
#                     28
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 21,
#                 "category": "logo",
#                 "group": "0",
#                 "bbox": [
#                     82.3,
#                     211.3,
#                     21,
#                     113,
#                     59
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 100,
#         "file_name": "IMG_1514.jpg",
#         "canvas_size": [
#             720,
#             1486
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     360.0,
#                     741.7,
#                     0,
#                     720,
#                     1483
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     13,
#                     13,
#                     13,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     360.5,
#                     982.9,
#                     1,
#                     360,
#                     653
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     92.5,
#                     932.7,
#                     2,
#                     185,
#                     533
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     627.6,
#                     974.4,
#                     3,
#                     184,
#                     257
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     504.9,
#                     1353.8,
#                     4,
#                     208,
#                     179
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": null,
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": null,
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     361.0,
#                     105.7,
#                     5,
#                     386,
#                     105
#                 ],
#                 "raw_text": "0 day T \uba64\ubc84\uc2ed X \uc5d0\uc774\ub2f7 iPhone 16 \uc2dc\ub9ac\uc988 \ucd9c\uc2dc \uae30\ub150 \ud034\uc988",
#                 "text_newline": [
#                     "0 day T \uba64\ubc84\uc2ed X \uc5d0\uc774\ub2f7",
#                     "iPhone 16 \uc2dc\ub9ac\uc988 \ucd9c\uc2dc \uae30\ub150 \ud034\uc988"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     250,
#                     233,
#                     218,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     360.1,
#                     309.2,
#                     6,
#                     596,
#                     247
#                 ],
#                 "raw_text": "\uc2a4\ud0c0\ubc85\uc2a4 \uce74\ud398 \uc544\uba54\ub9ac\uce74\ub178(Tall) 1\uc794 \uc751\ubaa8 \ud034\uc988 \uc774\ubca4\ud2b8",
#                 "text_newline": [
#                     "\uc2a4\ud0c0\ubc85\uc2a4 \uce74\ud398",
#                     "\uc544\uba54\ub9ac\uce74\ub178(Tall) 1\uc794",
#                     "\uc751\ubaa8 \ud034\uc988 \uc774\ubca4\ud2b8"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     245,
#                     213,
#                     197,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     360.7,
#                     506.7,
#                     7,
#                     538,
#                     68
#                 ],
#                 "raw_text": "\ud034\uc988 \uc815\ub2f5\uc744 \ub9de\ud78c \uace0\uac1d\ub2d8 5,000\uba85\uc744 \ucd94\ucca8\ud574 \uc2a4\ud0c0\ubc85\uc2a4 \uce74\ud398 \uc544\uba54\ub9ac\uce74\ub178(Tall) 1\uc794 \ucfe0\ud3f0\uc744 \ub4dc\ub9bd\ub2c8\ub2e4.",
#                 "text_newline": [
#                     "\ud034\uc988 \uc815\ub2f5\uc744 \ub9de\ud78c \uace0\uac1d\ub2d8 5,000\uba85\uc744 \ucd94\ucca8\ud574",
#                     "\uc2a4\ud0c0\ubc85\uc2a4 \uce74\ud398 \uc544\uba54\ub9ac\uce74\ub178(Tall) 1\uc794 \ucfe0\ud3f0\uc744 \ub4dc\ub9bd\ub2c8\ub2e4."
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     249,
#                     231,
#                     221,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": 0,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     }
# ]
# 변환된 JSON 파일 /content/output.json에 저장

# %% [markdown]
# # 10.18ver 보존

# %%
# main 원본

import os
from PIL import Image
import json

# 경로상 이미지 파일 width와 height 초기화
def get_image_dimensions(directory_path):
    image_dimensions = {}

    # 이미지 파일 순회
    for filename in os.listdir(directory_path):
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            file_path = os.path.join(directory_path, filename)
            with Image.open(file_path) as img:
                width, height = img.size
                image_dimensions[filename] = {"width": width, "height": height}

    return image_dimensions

# 인풋 경로
directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_test'

# 원본 raw data width, height 반영
image_info = get_image_dimensions(directory_path)


# 카테고리별 순서를 지정 -> 캐시미션 업데이트 후 group_underaly값 변경해야됨. -> 반영 10.17에 반영 예정
category_order = [
    "background", "group_underlay", "image", "sticker",
    "text_underlay", "decoration", "text", "item", "logo"
]

# JSON 데이터를 변환하는 함수
def convert_json(data, index, image_info):
    # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
    file_name = data['source']['fileName']
    if file_name in image_info:
        image_width = image_info[file_name]['width']
        image_height = image_info[file_name]['height']
        canvas_size = [image_width, image_height]
    else:
        # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
        canvas_size = [1, 1]

    # 파일 정보 변환
    new_data = {
        "id": index,  # id는 각 파일별로 고유하게 설정
        "file_name": data['source']['fileName'],
        "canvas_size": canvas_size,
        "type": "MMS",
        "elements": []
    }

    # units를 category_order에 따라 정렬
    # sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))
    # sorted_units = sorted(data['units'], key=lambda x: (
    # category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
    # x['coordinates']['y1'],  # 상단 기준 정렬
    # x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
    # ))
    sorted_units = sorted(
        [unit for unit in data['units'] if unit.get('status') != 'WRONG'],  # status가 "wrong"인 애들은 제외
        key=lambda x: (
            category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
            x['coordinates']['y1'],  # 상단 기준 정렬
            x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
        )
    )

    # element_id를 추적할 변수
    element_id = 0

    # 각 정렬된 unit항목 내 정보들 처리
    for unit in sorted_units:
        element = {
            "element_id": element_id,
            "category": unit['classClientId'],
            "group": None,  # 기본값 설정
            "bbox": [],  # 나중에 채워짐
            "raw_text": "",
            "text_newline": [],
            "text_alignment": "",
            "highlight_text": "",
            "font_color": [],
            "font_type": None,
            "font_size": None,
            "highlight_color": [],
            "is_gradient": None,
            "gradient_color": None,
            "is_background": 0,
            "background_color": []
        }

        # 좌표 처리 (bbox와 raw_bbox)
        x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

        # 이미지 크기 bbox 좌표 조건 반영
        center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
        center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
        box_width = int((x2 - x1) * canvas_size[0])
        box_height = int((y2 - y1) * canvas_size[1])

        # bbox 값 설정
        bbox = [center_x, center_y, element_id, box_width, box_height]
        element['bbox'] = bbox

        # background 조건 적용'

        if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element['group'] = None  # 기타 값 처리
          else:
            element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정

          selectionClientId_2 = unit['submissionItems'][1]['selectionClientIds'][0]
          element['is_background'] = 1 if selectionClientId_2 == "1000" else 2

          if element['is_background'] == 1:
            background_color = unit['submissionItems'][2]['answer']
            if "RGB" in background_color:
              rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
              rgb_values = [int(c) for c in rgb_values_str.split(",")]
              element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
            else:
              element['background_color'] = ["color error"]
          else:
            element['background_color'] = [file_name]









        # group_underlay 조건 적용
        elif unit['classClientId'] == "group_underlay" and len(unit['submissionItems']) > 1:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element['group'] = None  # 기타 값 처리
          else:
            element['group'] = None  # selectionClientIds가 비어있을 경우 None 설정

          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color error"]





        # image 조건 적용
        elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




        # sticker 조건 적용
        elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None

          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color error"]




        # text_underlay 조건 적용
        elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None

          background_color = unit['submissionItems'][1]['answer']
          if "RGB" in background_color:
            rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
            rgb_values = [int(c) for c in rgb_values_str.split(",")]
            element['background_color'] = rgb_values + [1]  # 마지막에 ,1 추가
          else:
            element['background_color'] = ["color"]




        # decoration 조건 적용
        elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




        # text 조건 적용
        elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None

          element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
          element['text_newline'] = unit['submissionItems'][2]['answer'].split("\n") if unit['submissionItems'][2]['answer'] else []


          if len(unit['submissionItems']) > 3 and unit['submissionItems'][3]['selectionClientIds']:
            selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
            if selectionClientId_4 == "1000":
              element['text_alignment'] = "middle"
            elif selectionClientId_4 == "1001":
              element['text_alignment'] = "left"
            elif selectionClientId_4 == "1002":
              element['text_alignment'] = "right"
          else:
            element['text_alignment'] = ""

          element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""





          if len(unit['submissionItems']) > 5 and unit['submissionItems'][5]['answer']:
            font_color = unit['submissionItems'][5]['answer']

            if "RGB" in font_color:
              rgb_values_str = font_color.replace("RGB(", "").replace(")", "")
              font_color = [int(c) for c in rgb_values_str.split(",")]
              element['font_color'] = font_color
            else:
              element['font_color'] = ["color_error"]
          else:
            element['font_color'] = []

          if len(unit['submissionItems']) > 6 and unit['submissionItems'][6]['answer']:
            highlight_color = unit['submissionItems'][6]['answer']

            if "RGB" in highlight_color:
              rgb_values_str = highlight_color.replace("RGB(", "").replace(")", "")
              highlight_color = [int(c) for c in rgb_values_str.split(",")]
              element['highlight_color'] = highlight_color
            else:
              element['highlight_color'] = ["color_error"]

          else:
            element['highlight_color'] = ["color_error"]






          # item 조건 적용
        elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None




          # logo 조건 적용
        elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
          if unit['submissionItems'][0]['selectionClientIds']:
            selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

            if selectionClientId_1 == "1000":
              element['group'] = None
            elif selectionClientId_1 == "1001":
              element['group'] = "0"
            elif selectionClientId_1 == "1002":
              element['group'] = "1"
            elif selectionClientId_1 == "1003":
              element['group'] = "2"
            else:
              element["group"] = None
          else:
            selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정
            element['group'] = None


        # element 추가
        new_data['elements'].append(element)

        # element_id 증가
        element_id += 1

    return new_data

file_path = '/content/poc_annotation.json'

# 줄 단위로 JSON 객체 로드
output_json_list = []
with open(file_path, 'r') as f:
    for index, line in enumerate(f):
        # 각 줄을 JSON 객체로 변환
        input_json = json.loads(line.strip())
        # 변환 실행
        output_json = convert_json(input_json, index, image_info)
        output_json_list.append(output_json)

# 변환된 JSON 리스트
print(json.dumps(output_json_list, indent=4))

# 변환된 JSON 저장
output_file_path = '/content/output.json'

with open(output_file_path, 'w', encoding='utf-8') as outfile:
    json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

print(f"변환된 JSON 파일 {output_file_path}에 저장")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-536d95ce8406> in <cell line: 403>()
#     406         input_json = json.loads(line.strip())
#     407         # 변환 실행
# --> 408         output_json = convert_json(input_json, index, image_info)
#     409         output_json_list.append(output_json)
#     410
#
# <ipython-input-6-536d95ce8406> in convert_json(data, index, image_info)
#     129           if element['is_background'] == 1:
#     130             background_color = unit['submissionItems'][2]['answer']
# --> 131             if "RGB" in background_color:
#     132               rgb_values_str = background_color.replace("RGB(", "").replace(")", "")
#     133               rgb_values = [int(c) for c in rgb_values_str.split(",")]
#
# TypeError: argument of type 'NoneType' is not iterable

# %% [markdown]
# # (안씀) 10.17 이전

# %%
#  # main 원본

# import os
# from PIL import Image
# import json

# # 경로상 이미지 파일 width와 height 초기화
# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일 순회
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             file_path = os.path.join(directory_path, filename)
#             with Image.open(file_path) as img:
#                 width, height = img.size
#                 image_dimensions[filename] = {"width": width, "height": height}

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정 -> 캐시미션 업데이트 후 group_underaly값 변경해야됨. -> 반영 10.16 group_underlay
# category_order = [
#     "background", "group_underlay", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     # sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))
#     # sorted_units = sorted(data['units'], key=lambda x: (
#     # category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#     # x['coordinates']['y1'],  # 상단 기준 정렬
#     # x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#     # ))
#     sorted_units = sorted(
#         [unit for unit in data['units'] if unit.get('status') != 'WRONG'],  # status가 "wrong"인 애들은 제외
#         key=lambda x: (
#             category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#             x['coordinates']['y1'],  # 상단 기준 정렬
#             x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#         )
#     )

#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox

#         # background 조건 적용
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             selectionClientId_2 = unit['submissionItems'][1]['selectionClientIds'][0]

#             element['group'] = None
#             element['is_background'] = 1 if selectionClientId_2 == "1000" else 2

#             background_color = unit['submissionItems'][2]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # group_underlay 조건 적용
#         elif unit['classClientId'] == "group_underaly" and len(unit['submissionItems']) > 1:
#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]
#         # image 조건 적용
#         elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#         # sticker 조건 적용
#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # text_underlay 조건 적용
#         elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # decoration 조건 적용
#         elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None if selectionClientId_1 == "1000" else None

#         # text 조건 적용
#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
#             if unit['submissionItems'][0]['selectionClientIds']:
#               selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             else:
#               selectionClientId_1 = None  # 리스트가 비어있으면 None으로 설정

#             element['group'] = None

#             element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
#             element['text_newline'] = unit['submissionItems'][2]['answer'].split("\n") if unit['submissionItems'][2]['answer'] else []

#             if len(unit['submissionItems']) > 3 and unit['submissionItems'][3]['selectionClientIds']:
#               selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
#               if selectionClientId_4 == "1000":
#                 element['text_alignment'] = "middle"
#               elif selectionClientId_4 == "1001":
#                 element['text_alignment'] = "left"
#               elif selectionClientId_4 == "1002":
#                 element['text_alignment'] = "right"
#             else:
#               element['text_alignment'] = ""

#             element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""

#             if len(unit['submissionItems']) > 5 and unit['submissionItems'][5]['answer']:
#               font_color = unit['submissionItems'][5]['answer'].split(",")
#             else:
#               font_color = []  # answer 값이 None일 경우 빈 리스트로 처리
#             element['font_color'] = [int(c) if c.isdigit() else c for c in font_color if c]

#             if len(unit['submissionItems']) > 6 and unit['submissionItems'][6]['answer']:
#               highlight_color = unit['submissionItems'][6]['answer'].split(",")
#             else:
#               highlight_color = []
#             element['highlight_color'] = [int(c) if c.isdigit() else c for c in highlight_color if c]

#           # item 조건 적용
#         elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#           # logo 조건 적용
#         elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None


#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 로드
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")

# %% [markdown]
# # 안씀(빈 값 예외처리 없음)

# %%
# # 라디오 버튼 파싱기능 추가

# import os
# from PIL import Image
# import json

# # 경로상 이미지 파일 width와 height 초기화
# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일 순회
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             file_path = os.path.join(directory_path, filename)
#             with Image.open(file_path) as img:
#                 width, height = img.size
#                 image_dimensions[filename] = {"width": width, "height": height}

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정 -> 캐시미션 업데이트 후 group_underaly값 변경해야됨.
# category_order = [
#     "background", "group_underaly", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     # sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))
#     # sorted_units = sorted(data['units'], key=lambda x: (
#     # category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#     # x['coordinates']['y1'],  # 상단 기준 정렬
#     # x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#     # ))
#     sorted_units = sorted(
#         [unit for unit in data['units'] if unit.get('status') != 'WRONG'],  # status가 "wrong"인 애들은 제외
#         key=lambda x: (
#             category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#             x['coordinates']['y1'],  # 상단 기준 정렬
#             x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#         )
#     )

#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox

#         # background 조건 적용
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             selectionClientId_2 = unit['submissionItems'][1]['selectionClientIds'][0]

#             element['group'] = None
#             element['is_background'] = 1 if selectionClientId_2 == "1000" else 2

#             background_color = unit['submissionItems'][2]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # group_underlay 조건 적용
#         elif unit['classClientId'] == "group_underaly" and len(unit['submissionItems']) > 1:
#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]
#         # image 조건 적용
#         elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#         # sticker 조건 적용
#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # text_underlay 조건 적용
#         elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # decoration 조건 적용
#         elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None if selectionClientId_1 == "1000" else None

#         # text 조건 적용
#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:

#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]

#             element['group'] = None

#             element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
#             element['text_newline'] = unit['submissionItems'][2]['answer'].split(",") if unit['submissionItems'][2]['answer'] else []

#             selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
#             if selectionClientId_4 == "1000":
#                 element['text_alignment'] = "middle"
#             elif selectionClientId_4 == "1001":
#                 element['text_alignment'] = "left"
#             elif selectionClientId_4 == "1002":
#                 element['text_alignment'] = "right"

#             element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""

#             font_color = unit['submissionItems'][5]['answer'].split(",")
#             element['font_color'] = [int(c) if c.isdigit() else c for c in font_color if c]

#             highlight_color = unit['submissionItems'][6]['answer'].split(",") if unit['submissionItems'][6]['answer'] is not None else ""
#             highlight_color_list = highlight_color if highlight_color else []
#             element['highlight_color'] = [int(c) if c.isdigit() else c for c in highlight_color if c]

#           # item 조건 적용
#         elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#           # logo 조건 적용
#         elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None


#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 로드
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")

# %% [markdown]
# # 안씀 (\n 제외처리) -> 입력값 당시에 행 구분으로 파싱해오면 됨.

# %%
import json

# JSON 파일 경로 수정 (올바른 경로로)
input_file_path = '/content/output.json'
output_file_path = '/content/output_s.json'

# JSON 파일 불러오기
with open(input_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# \n 제거하는 함수
def remove_newlines_from_text_newline(obj):
    if isinstance(obj, list):
        return [item.replace('\n', '') if isinstance(item, str) else item for item in obj]
    elif isinstance(obj, dict):
        if 'text_newline' in obj:
            obj['text_newline'] = remove_newlines_from_text_newline(obj['text_newline'])
        return {key: remove_newlines_from_text_newline(value) for key, value in obj.items()}
    return obj

# 전체 데이터에서 \n 제거
cleaned_data = remove_newlines_from_text_newline(data)

# 결과를 새로운 파일에 저장 (output_s.json)
with open(output_file_path, 'w', encoding='utf-8') as file:
    json.dump(cleaned_data, file, ensure_ascii=False, indent=4)

print("모든 text_newline의 \\n이 제거되어 output_s.json에 저장되었습니다.")
# Out:
# 모든 text_newline의 \n이 제거되어 output_s.json에 저장되었습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## (안씀) status 미반영

# %%
# status 미반영
# # 라디오 버튼 파싱기능 추가

# import os
# from PIL import Image
# import json

# # 경로상 이미지 파일 width와 height 초기화
# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일 순회
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             file_path = os.path.join(directory_path, filename)
#             with Image.open(file_path) as img:
#                 width, height = img.size
#                 image_dimensions[filename] = {"width": width, "height": height}

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정
# category_order = [
#     "background", "group_underaly", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     # sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))
#     sorted_units = sorted(data['units'], key=lambda x: (
#     category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order),
#     x['coordinates']['y1'],  # 상단 기준 정렬
#     x['coordinates']['x1']   # 동일 상단일 경우 왼쪽 기준 정렬
#     ))
#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox

#         # background 조건 적용
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             selectionClientId_2 = unit['submissionItems'][1]['selectionClientIds'][0]

#             element['group'] = None
#             element['is_background'] = 1 if selectionClientId_2 == "1000" else 2

#             background_color = unit['submissionItems'][2]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # group_underlay 조건 적용
#         elif unit['classClientId'] == "group_underaly" and len(unit['submissionItems']) > 1:
#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]
#         # image 조건 적용
#         elif unit['classClientId'] == "image" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#         # sticker 조건 적용
#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # text_underlay 조건 적용
#         elif unit['classClientId'] == "text_underlay" and len(unit['submissionItems']) > 1:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             background_color = unit['submissionItems'][1]['answer'].split(",")
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color if c]

#         # decoration 조건 적용
#         elif unit['classClientId'] == "decoration" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None if selectionClientId_1 == "1000" else None

#         # text 조건 적용
#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#             element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
#             element['text_newline'] = unit['submissionItems'][2]['answer'].split(",") if unit['submissionItems'][2]['answer'] else []

#             selectionClientId_4 = unit['submissionItems'][3]['selectionClientIds'][0]
#             if selectionClientId_4 == "1000":
#                 element['text_alignment'] = "middle"
#             elif selectionClientId_4 == "1001":
#                 element['text_alignment'] = "left"
#             elif selectionClientId_4 == "1002":
#                 element['text_alignment'] = "right"

#             element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""

#             font_color = unit['submissionItems'][5]['answer'].split(",")
#             element['font_color'] = [int(c) if c.isdigit() else c for c in font_color if c]

#             highlight_color = unit['submissionItems'][6]['answer'].split(",") if unit['submissionItems'][6]['answer'] is not None else ""
#             highlight_color_list = highlight_color if highlight_color else []
#             element['highlight_color'] = [int(c) if c.isdigit() else c for c in highlight_color if c]

#           # item 조건 적용
#         elif unit['classClientId'] == "item" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None

#           # logo 조건 적용
#         elif unit['classClientId'] == "logo" and len(unit['submissionItems']) > 0:
#             selectionClientId_1 = unit['submissionItems'][0]['selectionClientIds'][0]
#             element['group'] = None


#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 로드
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")
# Out:
# [
#     {
#         "id": 0,
#         "file_name": "tdeal512.jpg",
#         "canvas_size": [
#             640,
#             860
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     430.0,
#                     0,
#                     640,
#                     860
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     235,
#                     226,
#                     229,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     275.3,
#                     1,
#                     640,
#                     550
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     235,
#                     226,
#                     229,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     705.3,
#                     2,
#                     640,
#                     309
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     325.7,
#                     333.3,
#                     3,
#                     521,
#                     385
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     127.3,
#                     551.9,
#                     4,
#                     160,
#                     162
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     255,
#                     90,
#                     32,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     462.3,
#                     74.1,
#                     5,
#                     261,
#                     52
#                 ],
#                 "raw_text": "\uc624\uc9c1 SK\ud154\ub808\ucf64 \uace0\uac1d\ub2d8\uaed8\ub9cc \ub4dc\ub9ac\ub294 \ud560\uc778 \ud61c\ud0dd!",
#                 "text_newline": [
#                     "\uc624\uc9c1 SK\ud154\ub808\ucf64",
#                     "\n\uace0\uac1d\ub2d8\uaed8\ub9cc \ub4dc\ub9ac\ub294 \ud560\uc778 \ud61c\ud0dd!"
#                 ],
#                 "text_alignment": "right",
#                 "highlight_text": "",
#                 "font_color": [
#                     56,
#                     52,
#                     110,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     128.8,
#                     553.5,
#                     6,
#                     112,
#                     101
#                 ],
#                 "raw_text": "55% \ud560\uc778",
#                 "text_newline": [
#                     "55%",
#                     "\n\ud560\uc778"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     460.8,
#                     674.9,
#                     7,
#                     259,
#                     22
#                 ],
#                 "raw_text": "\uad6c\ub9e4 \ub9cc\uc871\ub3c4 4.8 \u2605\u2605\u2605\u2605\u2605",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "\u2605\u2605\u2605\u2605\u2605",
#                 "font_color": [
#                     56,
#                     49,
#                     90,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     156,
#                     64,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     290.8,
#                     722.1,
#                     8,
#                     487,
#                     43
#                 ],
#                 "raw_text": "\ub77c\uc774\ud544 \uc800\ubd84\uc790 \ub354\ub9c8 \ucf5c\ub77c\uac90 2\ubcd1",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     67,
#                     69,
#                     118,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     211.2,
#                     792.0,
#                     9,
#                     328,
#                     49
#                 ],
#                 "raw_text": "T\ud61c\ud0dd\uac00 54,000\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "54,000\uc6d0",
#                 "font_color": [
#                     247,
#                     72,
#                     69,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     61,
#                     57,
#                     141,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     457.6,
#                     795.9,
#                     10,
#                     141,
#                     34
#                 ],
#                 "raw_text": "-119.000\uc6d0-",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     162,
#                     160,
#                     172,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "item",
#                 "group": null,
#                 "bbox": [
#                     393.0,
#                     606.5,
#                     11,
#                     125,
#                     46
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "item",
#                 "group": null,
#                 "bbox": [
#                     527.1,
#                     606.6,
#                     12,
#                     125,
#                     46
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     103.6,
#                     70.9,
#                     13,
#                     136,
#                     58
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     83.2,
#                     672.3,
#                     14,
#                     64,
#                     32
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 1,
#         "file_name": "tdeal1071.jpg",
#         "canvas_size": [
#             640,
#             860
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     430.0,
#                     0,
#                     640,
#                     860
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     224,
#                     224,
#                     224,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     173.3,
#                     1,
#                     640,
#                     346
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     224,
#                     224,
#                     224,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     321.1,
#                     543.1,
#                     2,
#                     637,
#                     387
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     239,
#                     239,
#                     241,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     799.1,
#                     3,
#                     640,
#                     121
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     224,
#                     224,
#                     224,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 4,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     533.4,
#                     4,
#                     583,
#                     285
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     318.5,
#                     280.6,
#                     5,
#                     243,
#                     62
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 6,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     313.2,
#                     775.9,
#                     6,
#                     376,
#                     49
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     249,
#                     101,
#                     101,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     35.1,
#                     117.3,
#                     7,
#                     70,
#                     96
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     318.9,
#                     147.4,
#                     8,
#                     484,
#                     198
#                 ],
#                 "raw_text": "\"9,900\uc6d0\" \uade0\uc77c\uac00\uc804",
#                 "text_newline": [
#                     "\"9",
#                     "900\uc6d0\"",
#                     "\n\uade0\uc77c\uac00\uc804"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "\"9,900\uc6d0\"",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     138,
#                     4,
#                     5,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     320.1,
#                     281.3,
#                     9,
#                     233,
#                     45
#                 ],
#                 "raw_text": "\ucd5c\ub300 94% \ud560\uc778",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.7,
#                     799.4,
#                     10,
#                     349,
#                     78
#                 ],
#                 "raw_text": "\uc2dd\ud488\ubd80\ud130 \uc0dd\ud65c\uc6a9\ud488\uae4c\uc9c0! \ucd08\ud2b9\uac00 \ub4dd\ud15c \ucc2c\uc2a4",
#                 "text_newline": [
#                     "\uc2dd\ud488\ubd80\ud130 \uc0dd\ud65c\uc6a9\ud488\uae4c\uc9c0!",
#                     "\n\ucd08\ud2b9\uac00 \ub4dd\ud15c \ucc2c\uc2a4"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "\uc2dd\ud488\ubd80\ud130 \uc0dd\ud65c\uc6a9\ud488\uae4c\uc9c0!",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     557.3,
#                     44.2,
#                     11,
#                     109,
#                     31
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 2,
#         "file_name": "tdeal983.jpg",
#         "canvas_size": [
#             640,
#             714
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     357.0,
#                     0,
#                     640,
#                     714
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 1,
#                 "background_color": [
#                     88,
#                     159,
#                     117,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     512.2,
#                     1,
#                     405,
#                     219
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     517.5,
#                     411.9,
#                     2,
#                     108,
#                     104
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 3,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     510.4,
#                     3,
#                     402,
#                     216
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     255,
#                     85,
#                     62,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 4,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     321.7,
#                     300.9,
#                     4,
#                     246,
#                     65
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     88,
#                     159,
#                     117,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     322.9,
#                     174.4,
#                     5,
#                     319,
#                     141
#                 ],
#                 "raw_text": "\uc78a\uc9c0 \ub9d0\uace0 \uc0ac\uc6a9\ud558\uc138\uc694!",
#                 "text_newline": [
#                     "\uc78a\uc9c0 \ub9d0\uace0",
#                     "\n\uc0ac\uc6a9\ud558\uc138\uc694!"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     318.9,
#                     302.1,
#                     6,
#                     203,
#                     33
#                 ],
#                 "raw_text": "\uc1fc\ud551 \uc9c0\uc6d0 \ucfe0\ud3f0",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     515.2,
#                     410.8,
#                     7,
#                     65,
#                     42
#                 ],
#                 "raw_text": "x2",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     83,
#                     64,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     319.4,
#                     513.3,
#                     8,
#                     198,
#                     141
#                 ],
#                 "raw_text": "5% \ubc14\ub85c \ud560\uc778 \ucfe0\ud3f0",
#                 "text_newline": [
#                     "5%",
#                     "\n\ubc14\ub85c \ud560\uc778 \ucfe0\ud3f0"
#                 ],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     319.4,
#                     673.0,
#                     9,
#                     369,
#                     26
#                 ],
#                 "raw_text": "\u203b\uc774 \ucfe0\ud3f0\uc740 \uc77c\ubd80 \uc0c1\ud488\uc5d0 \uc801\uc6a9\ub418\uc9c0 \uc54a\uc2b5\ub2c8\ub2e4.",
#                 "text_newline": [],
#                 "text_alignment": "middle",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     550.1,
#                     54.8,
#                     10,
#                     130,
#                     53
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     }
# ]
# 변환된 JSON 파일 /content/output.json에 저장

# %% [markdown]
# ## (안씀) 라디오 버튼값은 answer값에 지정이 안되어서 카테고리 별로 반영이 안되어있음.

# %%
# # 라디오 버튼값이 없음
# import os
# from PIL import Image
# import json

# # 경로상 이미지 파일 width와 height 초기화
# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일 순회
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             file_path = os.path.join(directory_path, filename)
#             with Image.open(file_path) as img:
#                 width, height = img.size
#                 image_dimensions[filename] = {"width": width, "height": height}

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정
# category_order = [
#     "background", "group_underaly", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))

#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox

#         # submissionItems 존재여부 확인
#         if 'submissionItems' in unit and len(unit['submissionItems']) > 0:
#             element['group'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else None

#         # 카테고리별 규칙 적용

#         # background 조건 적용
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
#             element['is_background'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else 0
#             background_color = unit['submissionItems'][2]['answer'].split(",")

#         # 숫자는 정수형으로, 문자는 그대로 저장 background ==2인 경우 파일 추출명 값으로 받아서 문자열은 그대로 처리함
#             element['background_color'] = [int(c) if c.isdigit() else c for c in background_color]

#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
#             element['group'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else None
#             element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
#             element['text_newline'] = unit['submissionItems'][2]['answer'].split(",") if unit['submissionItems'][2]['answer'] else []
#             element['text_alignment'] = unit['submissionItems'][3]['answer'] if unit['submissionItems'][3]['answer'] else ""
#             element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""

#           # 글자 색상과 하이라이트 글자 색상 처리
#             font_color = unit['submissionItems'][5]['answer'].split(",") if unit['submissionItems'][5]['answer'] else []
#             element['font_color'] = [int(c) for c in font_color if c.isdigit()]

#             highlight_color = unit['submissionItems'][6]['answer'].split(",") if unit['submissionItems'][6]['answer'] else []
#             element['highlight_color'] = [int(c) for c in highlight_color if c.isdigit()]

#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
#             element['background'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] else None

#         # 나머지 카테고리도 필요한 경우 동일한 방식으로 처리

#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 로드
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")
# Out:
# [
#     {
#         "id": 0,
#         "file_name": "filtered (11145).jpg",
#         "canvas_size": [
#             720,
#             1122
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     360.0,
#                     561.0,
#                     0,
#                     720,
#                     1122
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     "\ud655\uc7a5\uc790\ud3ec\ud568\ud30c\uc77c\uba85\uc785\ub825\ud544\uc694!"
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     360.0,
#                     992.8,
#                     1,
#                     720,
#                     258
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     373.2,
#                     796.6,
#                     2,
#                     102,
#                     101
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     325.7,
#                     91.8,
#                     3,
#                     66,
#                     64
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "005,080,059,1"
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     362.1,
#                     97.5,
#                     4,
#                     480,
#                     41
#                 ],
#                 "raw_text": "\uc2e0\uc120\ud55c \ube75\uc744 \uc9d1 \uc5d0\uc11c \ub9cc\ub098\ubcf4\uc138\uc694!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\uc9d1",
#                 "font_color": [
#                     5,
#                     80,
#                     59,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     358.1,
#                     283.8,
#                     5,
#                     517,
#                     271
#                 ],
#                 "raw_text": "\ub69c\ub808\uc96c\ub974 4\ucc9c\uc6d0 \ud560\uc778",
#                 "text_newline": [
#                     "\ub69c\ub808\uc96c\ub974",
#                     "\n4\ucc9c\uc6d0 \ud560\uc778"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     5,
#                     80,
#                     59,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     177.8,
#                     620.9,
#                     6,
#                     95,
#                     33
#                 ],
#                 "raw_text": "\uc6b0\ubb3c\uc6b0\ubb3c...",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     5,
#                     80,
#                     59,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     565.6,
#                     624.9,
#                     7,
#                     106,
#                     33
#                 ],
#                 "raw_text": "...\ub9db\uc788\ub2f9",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     5,
#                     80,
#                     59,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 1,
#         "file_name": "filtered (254).jpg",
#         "canvas_size": [
#             1079,
#             1078
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     539.5,
#                     539.0,
#                     0,
#                     1079,
#                     1078
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     204,
#                     243,
#                     106,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     543.7,
#                     802.2,
#                     1,
#                     639,
#                     491
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     188.8,
#                     577.0,
#                     2,
#                     205,
#                     62
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "255,255,255,1"
#             },
#             {
#                 "element_id": 3,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     947.9,
#                     611.4,
#                     3,
#                     160,
#                     63
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "255,255,255,1"
#             },
#             {
#                 "element_id": 4,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     540.6,
#                     114.3,
#                     4,
#                     499,
#                     73
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     543.7,
#                     483.9,
#                     5,
#                     602,
#                     82
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     116.3,
#                     170.8,
#                     6,
#                     85,
#                     83
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     968.1,
#                     399.6,
#                     7,
#                     55,
#                     83
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     217.0,
#                     962.6,
#                     8,
#                     60,
#                     78
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     539.6,
#                     112.8,
#                     9,
#                     393,
#                     46
#                 ],
#                 "raw_text": "\uc124\ud0d5 \ub300\uc2e0 \uc2a4\ud14c\ube44\uc544\ub85c!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\uc2a4\ud14c\ube44\uc544",
#                 "font_color": [
#                     206,
#                     241,
#                     132,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     542.6,
#                     222.8,
#                     10,
#                     706,
#                     84
#                 ],
#                 "raw_text": "\uc2a4\ud14c\ube44\uc544 \uc694\uad6c\ub974\ud2b8",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     48,
#                     46,
#                     70,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     543.3,
#                     353.2,
#                     11,
#                     756,
#                     146
#                 ],
#                 "raw_text": "\ucc10 \ud6c4\uae30 \ubd80\ud0c1\ud574",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\ucc10",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     250,
#                     255,
#                     109
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     539.6,
#                     481.5,
#                     12,
#                     493,
#                     41
#                 ],
#                 "raw_text": "1\uc6d4 5\uc77c ~ 1\uc6d4 14\uc77c 30\uba85 \ubaa8\uc9d1!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     48,
#                     46,
#                     70,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     187.6,
#                     574.5,
#                     13,
#                     149,
#                     40
#                 ],
#                 "raw_text": "\uce7c\ub85c\ub9ac Down",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     948.8,
#                     609.6,
#                     14,
#                     104,
#                     40
#                 ],
#                 "raw_text": "\ub2f9 Down",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 2,
#         "file_name": "filtered (4419).jpg",
#         "canvas_size": [
#             600,
#             849
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     424.5,
#                     0,
#                     600,
#                     849
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     239,
#                     135,
#                     48,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     255.2,
#                     1,
#                     600,
#                     510
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     681.2,
#                     2,
#                     600,
#                     335
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     547.3,
#                     3,
#                     600,
#                     336
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     143.7,
#                     320.7,
#                     4,
#                     45,
#                     41
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     312.5,
#                     312.7,
#                     5,
#                     53,
#                     37
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     466.6,
#                     291.9,
#                     6,
#                     45,
#                     32
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     203.6,
#                     89.7,
#                     7,
#                     37,
#                     22
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     395.4,
#                     89.4,
#                     8,
#                     39,
#                     20
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     300.2,
#                     169.5,
#                     9,
#                     400,
#                     195
#                 ],
#                 "raw_text": "\ub9d0\ub791\ub2ec\ucf64 \ucac0\ub4dd\ubcfc \u2981 Chewy Ball \u2981",
#                 "text_newline": [
#                     "\ub9d0\ub791\ub2ec\ucf64",
#                     "\n\ucac0\ub4dd\ubcfc",
#                     "\n\u2981 Chewy Ball \u2981"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\ub9d0\ub791\ub2ec\ucf64",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     157,
#                     46,
#                     1,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     143.8,
#                     374.3,
#                     10,
#                     105,
#                     59
#                 ],
#                 "raw_text": "\uce58\uc988\ucac0\ub4dd\ubcfc \uce58\uc988\uac00 \ucf55\ucf55! \ubc15\ud600\uc788\ub294 \ucac0\ub4dd\ubcfc",
#                 "text_newline": [
#                     "\uce58\uc988\ucac0\ub4dd\ubcfc",
#                     "\n\uce58\uc988\uac00 \ucf55\ucf55!",
#                     "\n\ubc15\ud600\uc788\ub294 \ucac0\ub4dd\ubcfc"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uce58\uc988\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     157,
#                     46,
#                     1,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     311.1,
#                     363.8,
#                     11,
#                     125,
#                     61
#                 ],
#                 "raw_text": "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc \uc625\uc218\uc218\uc54c\uc774 \ud1a1\ud1a1! \uc7ac\ubc0c\ub294 \uc2dd\uac10!",
#                 "text_newline": [
#                     "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc",
#                     "\n\uc625\uc218\uc218\uc54c\uc774 \ud1a1\ud1a1!",
#                     "\n\uc7ac\ubc0c\ub294 \uc2dd\uac10!"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     157,
#                     46,
#                     1,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     466.6,
#                     340.7,
#                     12,
#                     105,
#                     59
#                 ],
#                 "raw_text": "\uac10\uc790\ucac0\ub4dd\ubcfc \uac10\uc790 \ud06c\ub9bc\uc73c\ub85c \ub354 \uace0\uc18c\ud55c",
#                 "text_newline": [
#                     "\uac10\uc790\ucac0\ub4dd\ubcfc",
#                     "\n\uac10\uc790 \ud06c\ub9bc\uc73c\ub85c",
#                     "\n\ub354 \uace0\uc18c\ud55c"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uac10\uc790\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     157,
#                     46,
#                     1,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     126.7,
#                     783.9,
#                     13,
#                     174,
#                     17
#                 ],
#                 "raw_text": "\uc704 \uc774\ubbf8\uc9c0\ub294 \uc5f0\ucd9c\ub41c \uc774\ubbf8\uc9c0\uc785\ub2c8\ub2e4",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     404.6,
#                     754.7,
#                     14,
#                     334,
#                     79
#                 ],
#                 "raw_text": "1ea \uffe6 800",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 15,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     555.1,
#                     46.7,
#                     15,
#                     52,
#                     58
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 3,
#         "file_name": "filtered (45).jpg",
#         "canvas_size": [
#             1125,
#             1113
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     562.5,
#                     556.5,
#                     0,
#                     1125,
#                     1113
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     77,
#                     169,
#                     118,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     561.4,
#                     813.4,
#                     1,
#                     962,
#                     429
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     563.3,
#                     128.3,
#                     2,
#                     795,
#                     81
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     1016.4,
#                     520.4,
#                     3,
#                     123,
#                     151
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     563.5,
#                     126.2,
#                     4,
#                     676,
#                     48
#                 ],
#                 "raw_text": "\uc2dc\ud06c\ub9bf \ucfe0\ud3f0\uc774\ub2c8\uae50 \uac80\uc0c9\ud574\ub3c4 \uc548\ub098\uc640\uc694!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\uc2dc\ud06c\ub9bf \ucfe0\ud3f0",
#                 "font_color": [
#                     144,
#                     200,
#                     179,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     566.3,
#                     386.1,
#                     5,
#                     879,
#                     330
#                 ],
#                 "raw_text": "-\ucd5c\uc800\uac00 \uac80\uc0c9\ub9d0\uace0- \ud074\ub9ad\ud558\uc138\uc694",
#                 "text_newline": [
#                     "-\ucd5c\uc800\uac00 \uac80\uc0c9\ub9d0\uace0-",
#                     "\n\ud074\ub9ad\ud558\uc138\uc694"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     1034.9,
#                     85.7,
#                     6,
#                     83,
#                     90
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 4,
#         "file_name": "filtered (94).png",
#         "canvas_size": [
#             1000,
#             1318
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     659.0,
#                     0,
#                     1000,
#                     1318
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     29,
#                     27,
#                     41,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     331.0,
#                     1,
#                     1000,
#                     661
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     990.0,
#                     2,
#                     1000,
#                     656
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     722.0,
#                     332.5,
#                     3,
#                     556,
#                     664
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     323.6,
#                     1060.7,
#                     4,
#                     261,
#                     156
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "206,023,025,1"
#             },
#             {
#                 "element_id": 5,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     676.8,
#                     1060.3,
#                     5,
#                     259,
#                     156
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "206,023,025,1"
#             },
#             {
#                 "element_id": 6,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     501.4,
#                     796.1,
#                     6,
#                     197,
#                     69
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     300.3,
#                     321.7,
#                     7,
#                     316,
#                     171
#                 ],
#                 "raw_text": "WELCOME event \uc2e0\u2022\uaddc\u2022\uac00\u2022\uc785\u2022\ud61c\u2022\ud0dd",
#                 "text_newline": [
#                     "WELCOME",
#                     "\nevent",
#                     "\n\uc2e0\u2022\uaddc\u2022\uac00\u2022\uc785\u2022\ud61c\u2022\ud0dd"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "event",
#                 "font_color": [
#                     29,
#                     27,
#                     41,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     102,
#                     95,
#                     102,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     498.6,
#                     796.8,
#                     8,
#                     138,
#                     24
#                 ],
#                 "raw_text": "\uc911\ubcf5\ud560\uc778 \uac00\ub2a5\ucfe0\ud3f0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
# ...
#                     5,
#                     121,
#                     126
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "051,051,051,1"
#             },
#             {
#                 "element_id": 6,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     526.6,
#                     513.5,
#                     6,
#                     123,
#                     120
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "029,071,101,1"
#             },
#             {
#                 "element_id": 7,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     327.6,
#                     80.2,
#                     7,
#                     334,
#                     67
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     326.6,
#                     79.1,
#                     8,
#                     284,
#                     35
#                 ],
#                 "raw_text": "\uac00\uaca9, \ud488\uc9c8 \ubaa8\ub450 \ub9cc\uc871!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\ubaa8\ub450",
#                 "font_color": [
#                     28,
#                     69,
#                     98,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     245.3,
#                     275.4,
#                     9,
#                     416,
#                     66
#                 ],
#                 "raw_text": "T \ud61c\ud0dd\uac00 279,000\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     254,
#                     126,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     531.0,
#                     288.2,
#                     10,
#                     143,
#                     32
#                 ],
#                 "raw_text": "-1,099,000\uc6d0-",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     28,
#                     69,
#                     98,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.0,
#                     359.8,
#                     11,
#                     439,
#                     74
#                 ],
#                 "raw_text": "A\uae09\ub9ac\ud37c \uc0bc\uc131\uc804\uc790 \ub178\ud2b8\ubd81 NT371\uc2dc\ub9ac\uc988 (15.6\uc778\uce58/\uc778\ud154 i5/SSD 256GB)",
#                 "text_newline": [
#                     "A\uae09\ub9ac\ud37c \uc0bc\uc131\uc804\uc790 \ub178\ud2b8\ubd81 NT371\uc2dc\ub9ac\uc988",
#                     "\n(15.6\uc778\uce58/\uc778\ud154 i5/SSD 256GB)"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     51,
#                     54,
#                     56,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     527.2,
#                     515.1,
#                     12,
#                     76,
#                     74
#                 ],
#                 "raw_text": "75% \ud560\uc778",
#                 "text_newline": [
#                     "75%",
#                     "\n\ud560\uc778"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     527.6,
#                     626.2,
#                     13,
#                     60,
#                     71
#                 ],
#                 "raw_text": "\ubb34\ub8cc\ubc30\uc1a1",
#                 "text_newline": [
#                     "\ubb34\ub8cc",
#                     "\n\ubc30\uc1a1"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     318.8,
#                     178.7,
#                     14,
#                     363,
#                     68
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 9,
#         "file_name": "tdeal762.jpg",
#         "canvas_size": [
#             640,
#             860
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     320.0,
#                     430.0,
#                     0,
#                     640,
#                     860
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     126,
#                     191,
#                     245,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     250.6,
#                     389.7,
#                     1,
#                     501,
#                     600
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     472.4,
#                     539.3,
#                     2,
#                     335,
#                     641
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     133.2,
#                     236.2,
#                     3,
#                     171,
#                     39
#                 ],
#                 "raw_text": "#\ub9c8\uac10\uc784\ubc15!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     109,
#                     254,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     214.5,
#                     364.3,
#                     4,
#                     340,
#                     178
#                 ],
#                 "raw_text": "\ud55c\uc815 \uc218\ub7c9 \ud56b\ub51c \ud2b9\uac00",
#                 "text_newline": [
#                     "\ud55c\uc815 \uc218\ub7c9",
#                     "\n\ud56b\ub51c \ud2b9\uac00"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\ud56b\ub51c \ud2b9\uac00",
#                 "font_color": [
#                     4,
#                     30,
#                     31,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     0,
#                     109,
#                     254,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     189.1,
#                     516.3,
#                     5,
#                     292,
#                     52
#                 ],
#                 "raw_text": "\ucd5c\ub300 80% \ud560\uc778",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "80%",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     0,
#                     109,
#                     254,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     141.2,
#                     773.5,
#                     6,
#                     184,
#                     32
#                 ],
#                 "raw_text": "\u203b \uc7ac\uace0 \uc18c\uc9c4 \uc2dc \uc885\ub8cc",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     550.9,
#                     61.9,
#                     7,
#                     117,
#                     41
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     }
# ]
# 변환된 JSON 파일 /content/output.json에 저장

# %% [markdown]
# # (안씀) 변환조건 원본, background가 2일 경우에 대한 경우 처리 없음.

# %%
# import os
# from PIL import Image
# import json

# # 경로에 있는 이미지 파일의 width와 height를 기억하는 함수
# def get_image_dimensions(directory_path):
#     image_dimensions = {}

#     # 이미지 파일들을 순회
#     for filename in os.listdir(directory_path):
#         if filename.endswith(('.png', '.jpg', '.jpeg')):
#             file_path = os.path.join(directory_path, filename)
#             with Image.open(file_path) as img:
#                 width, height = img.size
#                 image_dimensions[filename] = {"width": width, "height": height}

#     return image_dimensions

# # 인풋 경로
# directory_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image'

# # 원본 raw data width, height 반영
# image_info = get_image_dimensions(directory_path)


# # 카테고리별 순서를 지정
# category_order = [
#     "background", "group_underaly", "image", "sticker",
#     "text_underlay", "decoration", "text", "item", "logo"
# ]

# # JSON 데이터를 변환하는 함수
# def convert_json(data, index, image_info):
#     # 파일 이름에 해당하는 width, height 딕셔너리 형태 키 값으로 반영
#     file_name = data['source']['fileName']
#     if file_name in image_info:
#         image_width = image_info[file_name]['width']
#         image_height = image_info[file_name]['height']
#         canvas_size = [image_width, image_height]
#     else:
#         # 이미지 크기가 없는 경우 기본값으로 세팅해놓음
#         canvas_size = [1, 1]

#     # 파일 정보 변환
#     new_data = {
#         "id": index,  # id는 각 파일별로 고유하게 설정
#         "file_name": data['source']['fileName'],
#         "canvas_size": canvas_size,
#         "type": "MMS",
#         "elements": []
#     }

#     # units를 category_order에 따라 정렬
#     sorted_units = sorted(data['units'], key=lambda x: category_order.index(x['classClientId']) if x['classClientId'] in category_order else len(category_order))

#     # element_id를 추적할 변수
#     element_id = 0

#     # 각 정렬된 unit항목 내 정보들 처리
#     for unit in sorted_units:
#         element = {
#             "element_id": element_id,
#             "category": unit['classClientId'],
#             "group": None,  # 기본값 설정
#             "bbox": [],  # 나중에 채워짐
#             "raw_text": "",
#             "text_newline": [],
#             "text_alignment": "",
#             "highlight_text": "",
#             "font_color": [],
#             "font_type": None,
#             "font_size": None,
#             "highlight_color": [],
#             "is_gradient": None,
#             "gradient_color": None,
#             "is_background": 0,
#             "background_color": []
#         }

#         # 좌표 처리 (bbox와 raw_bbox)
#         x1, y1, x2, y2 = unit['coordinates']['x1'], unit['coordinates']['y1'], unit['coordinates']['x2'], unit['coordinates']['y2']

#         # 이미지 크기 bbox 좌표 조건 반영
#         center_x = round((x1 + x2) / 2 * canvas_size[0], 1)
#         center_y = round((y1 + y2) / 2 * canvas_size[1], 1)
#         box_width = int((x2 - x1) * canvas_size[0])
#         box_height = int((y2 - y1) * canvas_size[1])

#         # bbox 값 설정
#         bbox = [center_x, center_y, element_id, box_width, box_height]
#         element['bbox'] = bbox

#         # submissionItems 존재여부 확인
#         if 'submissionItems' in unit and len(unit['submissionItems']) > 0:
#             element['group'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else None

#         # 카테고리별 규칙 적용
#         if unit['classClientId'] == "background" and len(unit['submissionItems']) > 2:
#             element['is_background'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else 0
#             background_color = unit['submissionItems'][2]['answer'].split(",")
#             element['background_color'] = [int(c) for c in background_color if c.isdigit()]


#         elif unit['classClientId'] == "text" and len(unit['submissionItems']) > 6:
#             element['group'] = unit['submissionItems'][0]['answer'] if unit['submissionItems'][0]['answer'] is not None else None
#             element['raw_text'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] is not None else ""
#             element['text_newline'] = unit['submissionItems'][2]['answer'].split(",") if unit['submissionItems'][2]['answer'] else []
#             element['text_alignment'] = unit['submissionItems'][3]['answer'] if unit['submissionItems'][3]['answer'] else ""
#             element['highlight_text'] = unit['submissionItems'][4]['answer'] if unit['submissionItems'][4]['answer'] else ""

#           # 폰트 색상과 하이라이트 색상 처리
#             font_color = unit['submissionItems'][5]['answer'].split(",") if unit['submissionItems'][5]['answer'] else []
#             element['font_color'] = [int(c) for c in font_color if c.isdigit()]

#             highlight_color = unit['submissionItems'][6]['answer'].split(",") if unit['submissionItems'][6]['answer'] else []
#             element['highlight_color'] = [int(c) for c in highlight_color if c.isdigit()]

#         elif unit['classClientId'] == "sticker" and len(unit['submissionItems']) > 1:
#             element['background'] = unit['submissionItems'][1]['answer'] if unit['submissionItems'][1]['answer'] else None

#         # 나머지 카테고리도 필요한 경우 동일한 방식으로 처리

#         # element 추가
#         new_data['elements'].append(element)

#         # element_id 증가
#         element_id += 1

#     return new_data

# file_path = '/content/poc_annotation.json'

# # 줄 단위로 JSON 객체 읽기
# output_json_list = []
# with open(file_path, 'r') as f:
#     for index, line in enumerate(f):
#         # 각 줄을 JSON 객체로 변환
#         input_json = json.loads(line.strip())
#         # 변환 실행
#         output_json = convert_json(input_json, index, image_info)
#         output_json_list.append(output_json)

# # 변환된 JSON 리스트 출력
# print(json.dumps(output_json_list, indent=4))

# # 변환된 JSON 저장
# output_file_path = '/content/output.json'

# with open(output_file_path, 'w', encoding='utf-8') as outfile:
#     json.dump(output_json_list, outfile, ensure_ascii=False, indent=4)

# print(f"변환된 JSON 파일 {output_file_path}에 저장")
# Out:
# [
#     {
#         "id": 0,
#         "file_name": "filtered (45).jpg",
#         "canvas_size": [
#             1125,
#             1113
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     562.5,
#                     556.5,
#                     0,
#                     1125,
#                     1113
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     77,
#                     169,
#                     118,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     561.8,
#                     813.7,
#                     1,
#                     963,
#                     428
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     561.0,
#                     125.6,
#                     2,
#                     793,
#                     75
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     1016.6,
#                     520.9,
#                     3,
#                     135,
#                     148
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     562.7,
#                     126.3,
#                     4,
#                     673,
#                     50
#                 ],
#                 "raw_text": "\uc2dc\ud06c\ub9bf \ucfe0\ud3f0\uc774\ub2c8\uae50 \uac80\uc0c9\ud574\ub3c4 \uc548\ub098\uc640\uc694!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\uc2dc\ud06c\ub9bf \ucfe0\ud3f0",
#                 "font_color": [
#                     138,
#                     212,
#                     185,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     568.1,
#                     384.0,
#                     5,
#                     882,
#                     335
#                 ],
#                 "raw_text": "-\ucd5c\uc800\uac00 \uac80\uc0c9\ub9d0\uace0- \ud074\ub9ad\ud558\uc138\uc694",
#                 "text_newline": [
#                     "-\ucd5c\uc800\uac00 \uac80\uc0c9\ub9d0\uace0-",
#                     "\n\ud074\ub9ad\ud558\uc138\uc694"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     1035.6,
#                     86.1,
#                     6,
#                     79,
#                     81
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 1,
#         "file_name": "filtered (94).png",
#         "canvas_size": [
#             1000,
#             1318
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     659.0,
#                     0,
#                     1000,
#                     1318
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     29,
#                     27,
#                     41,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     989.8,
#                     1,
#                     1000,
#                     656
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     500.0,
#                     329.9,
#                     2,
#                     1000,
#                     659
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     722.5,
#                     331.7,
#                     3,
#                     555,
#                     663
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     324.0,
#                     1060.5,
#                     4,
#                     262,
#                     156
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "206,023,025,1"
#             },
#             {
#                 "element_id": 5,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     678.2,
#                     1060.5,
#                     5,
#                     260,
#                     156
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "206,023,025,1"
#             },
#             {
#                 "element_id": 6,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     501.6,
#                     795.3,
#                     6,
#                     187,
#                     65
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     298.9,
#                     319.9,
#                     7,
#                     312,
#                     177
#                 ],
#                 "raw_text": "WELCOME event \uc2e0\u2981\uaddc\u2981\uac00\u2981\uc785\u2981\ud61c\u2981\ud0dd",
#                 "text_newline": [
#                     "WELCOME",
#                     "\nevent",
#                     "\n\uc2e0\u2981\uaddc\u2981\uac00\u2981\uc785\u2981\ud61c\u2981\ud0dd"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "event",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     101,
#                     95,
#                     101,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     498.6,
#                     796.3,
#                     8,
#                     140,
#                     33
#                 ],
#                 "raw_text": "\uc911\ubcf5\ud560\uc778 \uac00\ub2a5\ucfe0\ud3f0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     500.1,
#                     880.4,
#                     9,
#                     401,
#                     40
#                 ],
#                 "raw_text": "WELCOME COUPON",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     311.5,
#                     1061.0,
#                     10,
#                     128,
#                     95
#                 ],
#                 "raw_text": "\uc7a5\ubc14\uad6c\ub2c8 \uc911\ubcf5\ud560\uc778 20%",
#                 "text_newline": [
#                     "\uc7a5\ubc14\uad6c\ub2c8",
#                     "\n\uc911\ubcf5\ud560\uc778 20%"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     658.6,
#                     1058.4,
#                     11,
#                     152,
#                     92
#                 ],
#                 "raw_text": "\uc7a5\ubc14\uad6c\ub2c8 \uc911\ubcf5\ud560\uc778 6,000\uc6d0",
#                 "text_newline": [
#                     "\uc7a5\ubc14\uad6c\ub2c8",
#                     "\n\uc911\ubcf5\ud560\uc778 6",
#                     "000\uc6d0"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     321.5,
#                     1214.9,
#                     12,
#                     225,
#                     53
#                 ],
#                 "raw_text": "1\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5 \uac00\uc785\uc77c \ud3ec\ud568 10\uc77c \uc774\ub0b4",
#                 "text_newline": [
#                     "1\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5",
#                     "\n\uac00\uc785\uc77c \ud3ec\ud568 10\uc77c \uc774\ub0b4"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "1\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5",
#                 "font_color": [
#                     81,
#                     78,
#                     95,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     676.7,
#                     1216.9,
#                     13,
#                     223,
#                     53
#                 ],
#                 "raw_text": "2\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5 \uac00\uc785\uc77c \ud3ec\ud568 30\uc77c \uc774\ub0b4",
#                 "text_newline": [
#                     "2\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5",
#                     "\n\uac00\uc785\uc77c \ud3ec\ud568 30\uc77c \uc774\ub0b4"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "2\ub9cc\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc \uc0ac\uc6a9\uac00\ub2a5",
#                 "font_color": [
#                     81,
#                     78,
#                     95,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     225.9,
#                     93.0,
#                     14,
#                     165,
#                     185
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 2,
#         "file_name": "filtered (254).jpg",
#         "canvas_size": [
#             1079,
#             1078
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     539.5,
#                     539.0,
#                     0,
#                     1079,
#                     1078
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     206,
#                     245,
#                     102,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     541.6,
#                     802.2,
#                     1,
#                     626,
#                     488
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     188.3,
#                     577.0,
#                     2,
#                     204,
#                     63
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "255,255,255,1"
#             },
#             {
#                 "element_id": 3,
#                 "category": "sticker",
#                 "group": null,
#                 "bbox": [
#                     945.6,
#                     611.5,
#                     3,
#                     159,
#                     64
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [],
#                 "background": "255,255,255,1"
#             },
#             {
#                 "element_id": 4,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     539.5,
#                     112.5,
#                     4,
#                     498,
#                     74
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     543.7,
#                     482.7,
#                     5,
#                     602,
#                     80
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     117.3,
#                     170.9,
#                     6,
#                     87,
#                     84
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     968.8,
#                     398.3,
#                     7,
#                     53,
#                     77
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     215.1,
#                     963.4,
#                     8,
#                     54,
#                     76
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     543.0,
#                     116.0,
#                     9,
#                     392,
#                     47
#                 ],
#                 "raw_text": "\uc124\ud0d5 \ub300\uc2e0 \uc2a4\ud14c\ube44\uc544\ub85c!",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\uc2a4\ud14c\ube44\uc544",
#                 "font_color": [
#                     197,
#                     238,
#                     108,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     531.1,
#                     218.8,
#                     10,
#                     734,
#                     90
#                 ],
#                 "raw_text": "\uc2a4\ud14c\ube44\uc544 \uc694\uad6c\ub974\ud2b8",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     48,
#                     45,
#                     76,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     543.0,
#                     355.3,
#                     11,
#                     758,
#                     143
#                 ],
#                 "raw_text": "\ucc10 \ud6c4\uae30 \ubd80\ud0c1\ud574",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "\ucc10",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     250,
#                     255,
#                     109,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     540.2,
#                     482.0,
#                     12,
#                     494,
#                     39
#                 ],
#                 "raw_text": "1\uc6d4 5\uc77c ~ 1\uc6d4 14\uc77c 30\uba85 \ubaa8\uc9d1! ",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     48,
#                     45,
#                     76,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     185.5,
#                     574.9,
#                     13,
#                     153,
#                     39
#                 ],
#                 "raw_text": "\uce7c\ub85c\ub9ac Down",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     947.0,
#                     612.9,
#                     14,
#                     102,
#                     36
#                 ],
#                 "raw_text": "\ub2f9 Down",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 3,
#         "file_name": "filtered (4419).jpg",
#         "canvas_size": [
#             600,
#             849
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     424.5,
#                     0,
#                     600,
#                     849
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": [
#                     243,
#                     133,
#                     48,
#                     1
#                 ]
#             },
#             {
#                 "element_id": 1,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     680.3,
#                     1,
#                     600,
#                     337
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 2,
#                 "category": "group_underaly",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     255.8,
#                     2,
#                     600,
#                     511
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 3,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     300.0,
#                     545.9,
#                     3,
#                     600,
#                     336
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 4,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     142.9,
#                     321.3,
#                     4,
#                     47,
#                     37
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     310.9,
#                     312.9,
#                     5,
#                     50,
#                     37
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     465.9,
#                     291.0,
#                     6,
#                     47,
#                     34
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     203.4,
#                     90.1,
#                     7,
#                     37,
#                     17
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     396.0,
#                     90.1,
#                     8,
#                     37,
#                     16
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     299.1,
#                     170.0,
#                     9,
#                     404,
#                     196
#                 ],
#                 "raw_text": "\ub9d0\ub791\ub2ec\ucf64 \ucac0\ub4dd\ubcfc \u2981Chewy Ball\u2981",
#                 "text_newline": [
#                     "\ub9d0\ub791\ub2ec\ucf64",
#                     "\n\ucac0\ub4dd\ubcfc",
#                     "\n\u2981Chewy Ball\u2981"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\ub9d0\ub791\ub2ec\ucf64",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     149,
#                     28,
#                     17,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     143.6,
#                     373.3,
#                     10,
#                     104,
#                     61
#                 ],
#                 "raw_text": "\uce58\uc988\ucac0\ub4dd\ubcfc \uce58\uc988\uac00 \ucf55\ucf55! \ubc15\ud600\uc788\ub294 \ucac0\ub4dd\ubcfc",
#                 "text_newline": [
#                     "\uce58\uc988\ucac0\ub4dd\ubcfc",
#                     "\n\uce58\uc988\uac00 \ucf55\ucf55!",
#                     "\n\ubc15\ud600\uc788\ub294 \ucac0\ub4dd\ubcfc"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uce58\uc988\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     149,
#                     28,
#                     17,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     311.6,
#                     363.9,
#                     11,
#                     124,
#                     60
#                 ],
#                 "raw_text": "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc \uc625\uc218\uc218\uc54c\uc774 \ud1a1\ud1a1! \uc7ac\ubc0c\ub294 \uc2dd\uac10!",
#                 "text_newline": [
#                     "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc",
#                     "\n\uc625\uc218\uc218\uc54c\uc774 \ud1a1\ud1a1!",
#                     "\n\uc7ac\ubc0c\ub294 \uc2dd\uac10!"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uc625\uc218\uc218\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     149,
#                     28,
#                     17,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     466.9,
#                     340.8,
#                     12,
#                     105,
#                     60
#                 ],
#                 "raw_text": "\uac10\uc790\ucac0\ub4dd\ubcfc \uac10\uc790 \ud06c\ub9bc\uc73c\ub85c \ub354 \uace0\uc18c\ud55c",
#                 "text_newline": [
#                     "\uac10\uc790\ucac0\ub4dd\ubcfc",
#                     "\n\uac10\uc790 \ud06c\ub9bc\uc73c\ub85c",
#                     "\n\ub354 \uace0\uc18c\ud55c"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "\uac10\uc790\ucac0\ub4dd\ubcfc",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     149,
#                     28,
#                     17,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     127.0,
#                     784.4,
#                     13,
#                     176,
#                     16
#                 ],
#                 "raw_text": "\uc704 \uc774\ubbf8\uc9c0\ub294 \uc5f0\ucd9c\ub41c \uc774\ubbf8\uc9c0\uc785\ub2c8\ub2e4",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     405.3,
#                     754.6,
#                     14,
#                     332,
#                     78
#                 ],
#                 "raw_text": "1ea \\ 800",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 15,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     556.1,
#                     45.2,
#                     15,
#                     49,
#                     54
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     },
#     {
#         "id": 4,
#         "file_name": "filtered (9603).jpg",
#         "canvas_size": [
#             736,
#             736
#         ],
#         "type": "MMS",
#         "elements": [
#             {
#                 "element_id": 0,
#                 "category": "background",
#                 "group": null,
# ...
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 5,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     129.5,
#                     532.0,
#                     5,
#                     177,
#                     181
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 6,
#                 "category": "image",
#                 "group": null,
#                 "bbox": [
#                     128.8,
#                     720.8,
#                     6,
#                     180,
#                     178
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 7,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     319.7,
#                     127.0,
#                     7,
#                     228,
#                     57
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 8,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     300.9,
#                     379.1,
#                     8,
#                     95,
#                     54
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 9,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     301.6,
#                     568.6,
#                     9,
#                     95,
#                     52
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 10,
#                 "category": "text_underlay",
#                 "group": null,
#                 "bbox": [
#                     302.7,
#                     756.7,
#                     10,
#                     97,
#                     54
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 11,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     87.8,
#                     198.3,
#                     11,
#                     65,
#                     59
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 12,
#                 "category": "decoration",
#                 "group": null,
#                 "bbox": [
#                     553.4,
#                     198.3,
#                     12,
#                     73,
#                     62
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 13,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     320.3,
#                     73.8,
#                     13,
#                     180,
#                     27
#                 ],
#                 "raw_text": "\ucd5c\uadfc \uad00\uc2ec \uc788\uc73c\uc168\ub358",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 14,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     319.8,
#                     127.7,
#                     14,
#                     144,
#                     34
#                 ],
#                 "raw_text": "\uc778\uae30\uac04\ud3b8\uc2dd",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     76,
#                     38,
#                     255,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 15,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     319.5,
#                     197.0,
#                     15,
#                     374,
#                     57
#                 ],
#                 "raw_text": "\uc694\uc998 \ud56b\ud55c \uc544\uc774\ud15c",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     220,
#                     2,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 16,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     418.0,
#                     313.1,
#                     16,
#                     329,
#                     52
#                 ],
#                 "raw_text": "[\uc9d1\uc5d0\uc11c\uba39\uc790] \uacf1\uc774\uace0\uc6b4 \uc18c\uacf1\ucc3d(160g)+\ucc38\uc18c\uc2a4(20g) \uc99d\uc815 \uc678 5\uc885",
#                 "text_newline": [
#                     "[\uc9d1\uc5d0\uc11c\uba39\uc790] \uacf1\uc774\uace0\uc6b4 \uc18c\uacf1\ucc3d(160g)+\ucc38",
#                     "\n\uc18c\uc2a4(20g) \uc99d\uc815 \uc678 5\uc885"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 17,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     366.9,
#                     380.1,
#                     17,
#                     198,
#                     36
#                 ],
#                 "raw_text": "47% 6,900\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "47%",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 18,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     389.3,
#                     501.3,
#                     18,
#                     274,
#                     55
#                 ],
#                 "raw_text": "[\ucc38\ub2e4\ub978] \ucd98\ucc9c\uc9c1\uc1a1 \uc21c\uc0b4 \ucd98\ucc9c\ub2ed\uac08\ube44(500g)1+1\ud329 \uc678 2\uc885",
#                 "text_newline": [
#                     "[\ucc38\ub2e4\ub978] \ucd98\ucc9c\uc9c1\uc1a1 \uc21c\uc0b4 \ucd98\ucc9c\ub2ed\uac08\ube44",
#                     "\n(500g)1+1\ud329 \uc678 2\uc885"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 19,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     367.5,
#                     568.9,
#                     19,
#                     203,
#                     33
#                 ],
#                 "raw_text": "70% 9,900\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "70%",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 20,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     422.0,
#                     690.1,
#                     20,
#                     337,
#                     54
#                 ],
#                 "raw_text": "[\uc678\uac13\uc9d1] \uc1a1\ud0c4 \uc11c\uc815\ub9ac \ubd80\ub300\ucc0c\uac1c(550g) 5\ud329 \uc678 9\uc885",
#                 "text_newline": [
#                     "[\uc678\uac13\uc9d1] \uc1a1\ud0c4 \uc11c\uc815\ub9ac \ubd80\ub300\ucc0c\uac1c(550g) 5\ud329",
#                     "\n\uc678 9\uc885"
#                 ],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 21,
#                 "category": "text",
#                 "group": null,
#                 "bbox": [
#                     375.7,
#                     758.5,
#                     21,
#                     217,
#                     36
#                 ],
#                 "raw_text": "50% 19,900\uc6d0",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "50%",
#                 "font_color": [
#                     0,
#                     0,
#                     0,
#                     1
#                 ],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [
#                     255,
#                     255,
#                     255,
#                     1
#                 ],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             },
#             {
#                 "element_id": 22,
#                 "category": "logo",
#                 "group": null,
#                 "bbox": [
#                     572.8,
#                     36.7,
#                     22,
#                     80,
#                     27
#                 ],
#                 "raw_text": "",
#                 "text_newline": [],
#                 "text_alignment": "",
#                 "highlight_text": "",
#                 "font_color": [],
#                 "font_type": null,
#                 "font_size": null,
#                 "highlight_color": [],
#                 "is_gradient": null,
#                 "gradient_color": null,
#                 "is_background": 0,
#                 "background_color": []
#             }
#         ]
#     }
# ]
# 변환된 JSON 파일 /content/output.json에 저장

# %% [markdown]
# # 좌표 매칭 잘 되었는지 상품 이미지 시각화 테스트

# %%
# bbox 좌표 테스트

import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# 이미지 경로
image_path = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_test/IMG_1862.JPG'


# 주어진 좌표
center_x = 203.7
center_y = 413.2
width = 287
height = 135


# bounding box 좌표 계산
x1 = center_x - width / 2
y1 = center_y - height / 2
x2 = center_x + width / 2
y2 = center_y + height / 2

# 이미지 열기
image = Image.open(image_path)

# 이미지를 그리기 위한 객체 생성
draw = ImageDraw.Draw(image)

# bounding box 그리기 (red 색상, 두께 2)
draw.rectangle([x1, y1, x2, y2], outline="red", width=4)

# 이미지 시각화
plt.imshow(image)
plt.axis('off')  # 축 숨기기
plt.show()

# %% [markdown]
# # element_id 부여한 크롭 이미지 저장 후 소령님 전달

# %%
import os
import json
from PIL import Image

# 변환된 JSON 파일 경로
json_file_path = '/content/output.json'

# 변환된 JSON 데이터 로드
with open(json_file_path, 'r') as file:
    data = json.load(file)

# raw data 경로
image_directory = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_1022'

# 저장 경로
output_directory = '/content/cropped_images_ver6'

# 저장할 디렉터리 생성
os.makedirs(output_directory, exist_ok=True)

# JSON 데이터 파싱 및 이미지 크롭
for item in data:
    file_name = item['file_name']
    image_path = os.path.join(image_directory, file_name)

    # 이미지 로드
    if os.path.exists(image_path):
        img = Image.open(image_path)
        image_width, image_height = img.size

        # image category 찾기
        image_found = False
        for element in item['elements']:
            if element['category'] == 'image':
                image_found = True
                element_id = element['element_id']

                # bbox 값 가져오기
                center_x, center_y, _, box_width, box_height = element['bbox']

                # 좌표 계산
                x1 = max(0, int(center_x - box_width / 2))
                y1 = max(0, int(center_y - box_height / 2))
                x2 = min(image_width, int(center_x + box_width / 2))
                y2 = min(image_height, int(center_y + box_height / 2))

                # 이미지 크롭
                cropped_img = img.crop((x1, y1, x2, y2))

                # 새로운 파일 이름 생성
                file_name_without_ext = os.path.splitext(file_name)[0]  # 파일 이름에서 확장자 제거
                new_file_name = f"{file_name_without_ext}-{element_id}.png"
                output_path = os.path.join(output_directory, new_file_name)
                # new_file_name = f"{file_name[:-4]}-{element_id}.png"
                # output_path = os.path.join(output_directory, new_file_name)

                # 크롭된 이미지 저장
                cropped_img.save(output_path)
                print(f"이미지 저장 {output_path}")

        # image 카테고리가 없을 경우 메시지 출력
        if not image_found:
            print(f"{file_name}에 image category 없음.")
    else:
        print(f"이미지 파일을 없음: {image_path}")
# Out:
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (40)-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal725-2.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (23)-3.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (23)-4.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (36)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (29)-3.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (3)-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal726-3.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (22)-2.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (8)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (8)-2.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (33)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (5)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (1)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (31)-1.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (31)-2.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (13)-2.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (10)-3.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (26)-3.png
# 이미지 저장 /content/cropped_images_ver6/ucubeImage1 (39)-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal547-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal555-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal555-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal541-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal713-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal721-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal721-5.png
# 이미지 저장 /content/cropped_images_ver6/tdeal532-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal715-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal720-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal535-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal722-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal717-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal533-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal533-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal556-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal563-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal554-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal719-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal525-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1517-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal518-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal518-5.png
# 이미지 저장 /content/cropped_images_ver6/tdeal518-6.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (12)-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal508-2.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (8)-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal526-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal531-2.png
# 이미지 저장 /content/cropped_images_ver6/tdeal531-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal531-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal510-1.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (11)-3.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (11)-4.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (19)-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal529-3.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (6)-3.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (6)-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal505-3.png
# 이미지 저장 /content/cropped_images_ver6/tdeal505-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal513-1.png
# 이미지 저장 /content/cropped_images_ver6/kdeal (16)-3.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1506-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1479-1.png
# IMG_1481.jpg에 image category 없음.
# 이미지 저장 /content/cropped_images_ver6/IMG_1512-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1507-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1501-1.png
# 이미지 저장 /content/cropped_images_ver6/File_295-1.png
# 이미지 저장 /content/cropped_images_ver6/File_233-3.png
# 이미지 저장 /content/cropped_images_ver6/File_233-4.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1513-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1478-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1511-1.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1511-2.png
# 이미지 저장 /content/cropped_images_ver6/File_247-1.png
# 이미지 저장 /content/cropped_images_ver6/File_332-1.png
# 이미지 저장 /content/cropped_images_ver6/186431-1.png
# 이미지 저장 /content/cropped_images_ver6/0408281646488320994866-1.png
# 이미지 저장 /content/cropped_images_ver6/0410161927048066026149-1.png
# 이미지 저장 /content/cropped_images_ver6/0405311704338054321731-2.png
# 이미지 저장 /content/cropped_images_ver6/0405311704338054321731-3.png
# 이미지 저장 /content/cropped_images_ver6/File_213-1.png
# 이미지 저장 /content/cropped_images_ver6/112056-2.png
# 이미지 저장 /content/cropped_images_ver6/142769-1.png
# 이미지 저장 /content/cropped_images_ver6/0408141153018348932048-1.png
# 이미지 저장 /content/cropped_images_ver6/0408141153018348932048-2.png
# 이미지 저장 /content/cropped_images_ver6/0408141153018348932048-3.png
# 이미지 저장 /content/cropped_images_ver6/File_183-2.png
# 이미지 저장 /content/cropped_images_ver6/File_183-3.png
# 이미지 저장 /content/cropped_images_ver6/0406011103258150837590-1.png
# 이미지 저장 /content/cropped_images_ver6/0406011103258150837590-2.png
# 이미지 저장 /content/cropped_images_ver6/0406011103258150837590-3.png
# 이미지 저장 /content/cropped_images_ver6/20211104092535_1-1.png
# 이미지 저장 /content/cropped_images_ver6/0409021235118333267139 (1)-1.png
# 이미지 저장 /content/cropped_images_ver6/0407291707298118175307-3.png
# 이미지 저장 /content/cropped_images_ver6/0401031514048272530315-1.png
# 이미지 저장 /content/cropped_images_ver6/0405201255208365859031-1.png
# 이미지 저장 /content/cropped_images_ver6/0310231733478369401211-1.png
# 이미지 저장 /content/cropped_images_ver6/0311101214348077187546-4.png
# 이미지 저장 /content/cropped_images_ver6/0405241241308115116184-1.png
# 이미지 저장 /content/cropped_images_ver6/0311151437168048606223-1.png
# 이미지 저장 /content/cropped_images_ver6/0310261710468658813794-1.png
# 이미지 저장 /content/cropped_images_ver6/0310231425428360195274-2.png
# 이미지 저장 /content/cropped_images_ver6/0403061200248374628350-2.png
# 이미지 저장 /content/cropped_images_ver6/0405311328548350627431-1.png
# 이미지 저장 /content/cropped_images_ver6/0309061241318298765995-1.png
# 이미지 저장 /content/cropped_images_ver6/0310051442188236195014-1.png
# 이미지 저장 /content/cropped_images_ver6/0310051442188236195014-2.png
# 이미지 저장 /content/cropped_images_ver6/0308081209428034430251-1.png
# 이미지 저장 /content/cropped_images_ver6/0309181639328307925536-1.png
# 이미지 저장 /content/cropped_images_ver6/0308021253178348702100-1.png
# 이미지 저장 /content/cropped_images_ver6/0308031018108177619615-1.png
# 이미지 저장 /content/cropped_images_ver6/0309081029098217614257-1.png
# 이미지 저장 /content/cropped_images_ver6/0404171353318345670867-1.png
# 이미지 저장 /content/cropped_images_ver6/0404171353318345670867-2.png
# 이미지 저장 /content/cropped_images_ver6/0404171353318345670867-3.png
# 이미지 저장 /content/cropped_images_ver6/0404171353318345670867-4.png
# 이미지 저장 /content/cropped_images_ver6/0403041333308326424253-3.png
# 이미지 저장 /content/cropped_images_ver6/0311211622578297345055-1.png
# 이미지 저장 /content/cropped_images_ver6/0309081441558362268635-1.png
# 이미지 저장 /content/cropped_images_ver6/0408021210378020602914-1.png
# 이미지 저장 /content/cropped_images_ver6/0408231530548090530241-1.png
# 이미지 저장 /content/cropped_images_ver6/File_269-1.png
# 이미지 저장 /content/cropped_images_ver6/tdeal538-4.png
# 이미지 저장 /content/cropped_images_ver6/tdeal538-5.png
# 이미지 저장 /content/cropped_images_ver6/tdeal538-6.png
# 이미지 저장 /content/cropped_images_ver6/IMG_1514-1.png

# %%
import os
import shutil
os.getcwd()
# Out:
# '/content'

# %%
import shutil
shutil.make_archive("product_image1023_ver6","zip","/content/cropped_images_ver6")
# Out:
# '/content/product_image1023_ver6.zip'

# %% [markdown]
# # 상품 추출 이미지 넘버링 csv

# %%
import pandas as pd
import json
from natsort import natsorted

# JSON 파일 경로
json_file_path = '/content/output.json'

# JSON 데이터 로드
with open(json_file_path, 'r') as file:
    data = json.load(file)

# 빈 리스트로 데이터프레임 생성 준비
data_list = []

# JSON 데이터 파싱
for item in data:
    file_name = item['file_name']
    for element in item['elements']:
        if element['category'] == 'image':
            element_id = element['element_id']
            new_file_name = f"{file_name[:-4]}-{element_id}.png"  # .jpg 제거 후 _element_id 추가
            data_list.append({"filename": new_file_name})

# 데이터프레임 생성
df = pd.DataFrame(data_list)

# filename 컬럼을 자연스러운 방식(natural order)으로 정렬
df_sorted = df.reindex(natsorted(df['filename'].tolist()))

# 정렬된 데이터프레임 표시
display(df_sorted)

# 정렬된 데이터프레임을 CSV 파일로 저장
output_csv_path = '/content/output_sorted.csv'
df_sorted.to_csv(output_csv_path, index=True)

print(f'정렬된 CSV 파일이 생성되었습니다: {output_csv_path}')
# Out:
#                filename
# IMG_1862-1.png      NaN
# IMG_1862-2.png      NaN
# 정렬된 CSV 파일이 생성되었습니다: /content/output_sorted.csv

# %%
# 크롭된 이미지 추출

import os
import json
from PIL import Image

# 변환된 JSON 파일 경로
json_file_path = '/content/output.json'

# 변환된 JSON 데이터 로드
with open(json_file_path, 'r') as file:
    data = json.load(file)

# raw data 경로
image_directory = '/content/drive/MyDrive/PM1팀/이호은/24-ds-127_SKT_AI_Media/Dataset/00_POC_dataset/03_layout_dataset/raw_image_test'

# 저장 경로
output_directory = '/content/cropped_images'

# 저장할 디렉터리 생성
os.makedirs(output_directory, exist_ok=True)

# JSON 데이터 파싱 및 이미지 크롭
for item in data:
    file_name = item['file_name']
    image_path = os.path.join(image_directory, file_name)

    # 이미지 로드
    if os.path.exists(image_path):
        img = Image.open(image_path)
        image_width, image_height = img.size

        # image category 찾기
        image_found = False
        for element in item['elements']:
            if element['category'] == 'image':
                image_found = True
                element_id = element['element_id']

                # bbox 값 가져오기
                center_x, center_y, _, box_width, box_height = element['bbox']

                # 좌표 계산
                x1 = max(0, int(center_x - box_width / 2))
                y1 = max(0, int(center_y - box_height / 2))
                x2 = min(image_width, int(center_x + box_width / 2))
                y2 = min(image_height, int(center_y + box_height / 2))

                # 이미지 크롭
                cropped_img = img.crop((x1, y1, x2, y2))

                # 새로운 파일 이름 생성
                new_file_name = f"{file_name[:-4]}-{element_id}"
                output_path = os.path.join(output_directory, new_file_name)

                # 크롭된 이미지 저장
                cropped_img.save(output_path)
                print(f"이미지 저장 {output_path}")

        # image 카테고리가 없을 경우 메시지 출력
        if not image_found:
            print(f"{file_name}에 image category 없음.")
    else:
        print(f"이미지 파일 없음: {image_path}")
# Out:
# 이미지 저장 /content/cropped_images/IMG_1862-1.png
# 이미지 저장 /content/cropped_images/IMG_1862-2.png

# %% [markdown]
# # 생성된 json 파일 검수
# ## 1. text_alignment 값이 left나 right인 경우에 text_newline의 원소가 2개보다 적은 경우
# ## 2. highlight_color 값이 있을 때 highlight_text가 없는 경우
# ## 3. highlight_text가 있을 때 highlight_color 값이 없는 경우
# ## 4. highlight_text가 있을 시 해당 값이 raw_text의 일부분으로 존재하는지 확인

# %%
# Out:
# 검수 결과가 valid_errors.json 파일로 저장됨
